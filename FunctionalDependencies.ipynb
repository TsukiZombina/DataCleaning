# %% [markdown]
# # Dependencias Funcionales

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Carga los datos del archivo .csv en un data frame de pandas.

# %%
df = pd.read_csv('InfoNeza/Delitos/Delitos.csv')
df = df.drop(columns = ['ID', 'X', 'Y'])

# %%
print(df.columns)
print(df.head(5))
# Out:
# Index(['HORA', 'FECHA', 'MES', 'DELITO', 'CALLE', 'No.', 'ENTRE_CALLE_1',
#        'ENTRE_CALLE_2', 'COLONIA', 'SECTOR', 'CUADRANTE', 'TURNO'],
#       dtype='object')
#             HORA     FECHA    MES            DELITO            CALLE  No.  \
# 0  22:30 A 04:00  1/1/2016  ENERO  ROBO DE VEHICULO  VALLE DE MEXICO  NaN
# 1           6:40  1/1/2016  ENERO  ROBO DE VEHICULO    RANCHO GRANDE  NaN
# 2          13:30  1/1/2016  ENERO  ROBO DE VEHICULO         LAURELES  NaN
# 3  03:00 A 05:00  1/1/2016  ENERO  ROBO DE VEHICULO    LAGO GRAN OSO   99
# 4          14:00  1/1/2016  ENERO  ROBO DE VEHICULO    LA CHAPARRITA  NaN
#
#        ENTRE_CALLE_1      ENTRE_CALLE_2                      COLONIA  SECTOR  \
# 0  VALLE DE YANG TSE     VALLE DE YUKON  VALLE DE ARAGON 1ra SECCION     1.0
# 1  AV. CARMELO PEREZ                NaN            BENITO JUAREZ III    11.0
# 2      CIELITO LINDO                NaN             BENITO JUAREZ II    10.0
# 3        AV. PIRULES                NaN                    AGUA AZUL     9.0
# 4             4ta AV  AMANECER RANCHERO            BENITO JUAREZ III    11.0
#
#   CUADRANTE  TURNO
# 0      C013      1
# 1      C112      1
# 2      C108      2
# 3      C095      1
# 4      C116      2

# %% [markdown]
# ## Algoritmo de fuerza bruta para encontrar dependencias funcionales
#
# El siguiente algoritmo de fuerza bruta determina las dependencias funcionales dados un data frame y dos columnas $c_{1}$ y $c_{2}$.

# %%
def get_fd(df, c1, c2):
    for value in df[c2].unique():
        # Get all entries that contain 'value' in c2
        df_value = df[df[c2] == value]
        
        # Check if all values in the column c1 are the same
        uniques = df_value[c1].unique()
        #print('Uniques of column {0} under {1} = {2}'.format(c1, c2, value))
        #print(len(uniques))
        
        if len(uniques) == 1:
            print('{0} = {1} -> {2} = {3}'.format(c2, value, c1, uniques[0]))

def search_fd(df):
    for c1 in df.columns:
        for c2 in df.columns:
            if c1 is not c2:
                get_fd(df, c1, c2)
                
search_fd(df)
# Out:
# FECHA = 3-Jul-17 -> HORA = 18:35
# FECHA = 6-Jul-17 -> HORA = 16:30
# FECHA = 12-Jul-17 -> HORA = 20:03
# FECHA = 13-Jul-17 -> HORA = 12:56
# FECHA = 15-Jul-17 -> HORA = 0:35
# FECHA = 30-Jul-17 -> HORA = 17:45
# FECHA = 1-Jul -> HORA = 14:00
# FECHA = 11-Jul -> HORA = 21:50
# FECHA = 12-Jul -> HORA = 8:36
# FECHA = 30-Jul -> HORA = 7:25
# FECHA = 31-Jul -> HORA = 7:20
# FECHA = 9-Jul -> HORA = 19:00
# FECHA = 08-ago-17 -> HORA = 2:55
# FECHA = 05-ago -> HORA = 6:50
# CALLE = CDA. BENITO JUAREZ -> HORA = 2:40
# CALLE = ATOTONILCO -> HORA = 19:00 A 20:00
# CALLE = ENRRAMADA -> HORA = 23:00
# CALLE = SERGIO -> HORA = 7:30
# CALLE = AV. CONSTITUCION DE LA  REPUBLICA -> HORA = 14:20
# CALLE = SALTO DE AGUA -> HORA = 7:50
# CALLE = VALLE DE SALINAS -> HORA = 22:10
# CALLE = GUADALUPE VICTORA -> HORA = 8:50
# CALLE = LA MALAGUENA -> HORA = 19:40
# CALLE = CALLE  13 -> HORA = 11:30
# CALLE = IGNACIO MANUEL ALTAMIRANO -> HORA = 10:40
# CALLE = AV. 701 -> HORA = 22:00
# CALLE = LA ENRAMADA -> HORA = 11:35
# CALLE = HACIEND DA LA NORIA -> HORA = 20:30
# No. = 800 -> HORA = 23:00 A 05:20
# No. = COND. 5 CASA 27 -> HORA = 20:45
# No. = MZ. 44 LT. 2 -> HORA = 16:55
# No. = MZ. 125 LT. 16 -> HORA = 19:42
# No. = 12-BIS -> HORA = 20:50
# No. = 443 -> HORA = 10:50
# No. = 30-B -> HORA = 20:20
# No. = FRENTE A LA MZ. 21 LT. 8 -> HORA = 20:19
# No. = 484 -> HORA = 03:00 A  10:0
# No. = 475 -> HORA = 14:29
# No. = 735 -> HORA = 15:50
# No. = 575 -> HORA = 10:40
# No. = 47-A -> HORA = 3:52
# No. = CASA 27 -> HORA = 21:15
# No. = 439 -> HORA = 18:30
# No. = 689 -> HORA = 9:56
# No. = MZ. 130, LT. 4 -> HORA = 11:50
# No. = 711 -> HORA = 13:30
# No. = 571 -> HORA = 17:37
# No. = MZ. 82 LT. 2 -> HORA = 21:20
# No. = MZ. 13, LT. 12 -> HORA = 16:20
# No. = MZ. 1, LT. 8 -> HORA = 5:00
# No. = 678 -> HORA = 18:00
# No. = MZ. 134, LT. 4 -> HORA = 12:00
# No. = 506 -> HORA = 17:03
# No. = 483 -> HORA = 20:40
# No. = 27 INT. 3 -> HORA = 20:30
# No. = MZ. 18 LT. 9 CASA D -> HORA = 20:54
# No. = 550 -> HORA = 10:00 A 12:15
# No. = 699 -> HORA = 00:00 A 09:00
# No. = MZ. 61 LT. 18 -> HORA = 12:00 A 14:00
# No. = 396 -> HORA = 04:00 A 18:25
# No. = 705 -> HORA = 21:30 A 21:40
# No. = LT.29 -> HORA = 02:30 A 07:30
# No. = 502 -> HORA = 21:30 A 08:00
# No. = 415 -> HORA = 21:30
# No. = MZ. 12 LT. 34 -> HORA = 0:50
# No. =  MZ-816, LT- 32 -> HORA = 06:015 A 06:30
# No. = 545 -> HORA = 14:00
# No. = 427 -> HORA = 23:00 A 09:00
# No. = 72 INT. 204 B -> HORA = 14:26
# No. = 417 DEPTO. 302 -> HORA = 11:45
# No. = 30 B -> HORA = 21:15
# No. = MZA 18 LT 47 -> HORA = 23:00 A 04:00
# No. = MZ. 11 LT. 1-A -> HORA = 10:51
# No. = MZ-149, LT-2 -> HORA = 14:00 A 19:00
# No. = MZ. 84, LT. 15 -> HORA = 13:55
# No. = MZ. 5, LT. 10 -> HORA = 11:17
# No. = MZ.28 LT.12 -> HORA = 14:00  A  14:05
# No. = EDIFICIO 7 MZ. 5 -> HORA = 20:13
# No. = MZ 16 LT 17 NO -> HORA = 21:50
# No. = 473 -> HORA = 22:30 A 22:45
# No. = MZ. 58 LT.4 -> HORA = 17:00
# No. = MZ. 42. LT. 1 -> HORA = 20:14
# No. = MZ 30 LT 4 -> HORA = 15:48
# No. = MZ-1, LT-22 -> HORA = 22:00
# No. = 615 -> HORA = 23:00 A 07:00
# No. = 5-C -> HORA = 16:24
# No. = 608 -> HORA = 19:05 A 19:45
# No. = MZ 17 LT 16 -> HORA = 23:05
# No. = MZ. 21 LT. 21 -> HORA = 12:08
# No. = MZ-55, LT-2 -> HORA = 22:00 A 06:00
# No. = MZ. 147 LT. 5 -> HORA = 14:30
# No. = MZ. 835 LT. 16 -> HORA = 07:30 A 07:45
# No. = 681 -> HORA = 19:00 A 05:00
# No. = 498 -> HORA = 7:20
# No. = MZ. 21, LT. 21 -> HORA = 0:25
# No. = 20-B -> HORA = 20:42
# No. = 124-BIS -> HORA = 23:15
# No. = 5-A -> HORA = 11:15 A 12:00
# No. = 20 INT. 2 -> HORA = 17:00 A 19:30
# No. = 408 -> HORA = 11:45
# No. = 411 -> HORA = 14:37
# No. = MZ. 25 LT. 41 -> HORA = 20:00 A 21:30
# No. = 445 -> HORA = 21:15
# No. = MZ. 11 LT. 18 -> HORA = 21:25
# No. = MZ. 18 LT. 18 -> HORA = 9:55
# No. = 165 INT. 5 -> HORA = 01:20 A 08:30
# No. = 476 -> HORA = 11:45
# No. = MZ. 75B LT. 1 -> HORA = 11:48
# No. = MZ. 133 LT. 8 -> HORA = 13:40
# No. = 81 BIS -> HORA = 20:00 A 00:25
# No. = 431 -> HORA = 20:26
# No. = 430 -> HORA = 10:09
# No. = 119 A -> HORA = 23:10
# No. = 125 CBIS -> HORA = 16:00 A 18:00
# No. = 18 INT 1 -> HORA = 22:30
# No. = MZ. 39 LT. 3 -> HORA = 15:17
# No. = MZ. 1 B2 LT. 21 -> HORA = 20:38
# No. = MZ. 103 LT. 31 -> HORA = 22:25
# No. = MZ-C, LT-6 -> HORA = 22:00
# No. = MZ. 73 LT. 6 -> HORA = 11:41
# No. = 444 -> HORA = 21:15
# No. = MZ. 33, LT. 17 -> HORA = 17:22
# No. = MZ. 90, LT. 6 -> HORA = 4:49
# No. = 43 INT. 1 -> HORA = 11:21
# No. = MZ-114, LT- 22 -> HORA = 22:00 A 06:00
# No. = MZ 6 LT 15 -> HORA = 20:15
# No. = MZ. 64 LT. 2 -> HORA = 22:15
# No. = MZ. 23, LT. 16 -> HORA = 6:14
# No. = 440 -> HORA = 07:30 A 09:00
# No. = 481 -> HORA = 20:26
# No. = 459 -> HORA = 18:15
# No. = MZ. 23 LT. 26 -> HORA = 10:59
# No. = MZ. 23 LT 32 -> HORA = 15:00  A 18:00
# No. = MZA 23 LT 36 -> HORA = 17:30  A 18:00
# No. = 806 -> HORA = 19:20
# No. = 163B -> HORA = 20:57
# No. = MZ. 25, LT 41A -> HORA = 09:00 A 19:30
# No. = EDIFICIO M5 -> HORA = 20:30
# No. = MZ. 98, LT. 14 -> HORA = 11:25
# No. = MZA 27 LT 16 -> HORA = 13:00
# No. = 142-B -> HORA = 12:05
# No. = 66-4 -> HORA = 20:30 A 21:30
# No. = FRENTE AL 374 -> HORA = 23:15
# No. = MZ. 25 -> HORA = 19:40
# No. = MZ. 23 A LT. 38 -> HORA = 21:30
# No. = MZ. 150, LT. 49 -> HORA = 4:05
# No. = 64 DEPTO 1 -> HORA = 21:00 A 08:30
# No. = MZ. 750 LT. 4 -> HORA = 21:10
# No. = 416 -> HORA = 20:38
# No. = MZ. 22 LT. 40 -> HORA = 14:20
# No. = MZA 53 -> HORA = 9:00
# No. = MZ. 9, LT. 17 -> HORA = 0:32
# No. = MZ-10, LT-9 -> HORA = 19:40
# No. = MZ 22 LT 3A -> HORA = 23:00 A 23:20
# No. = 409 -> HORA = 14:22
# No. = 543 -> HORA = 13:12
# No. = 709 -> HORA = 13:27
# No. = 15 MZA 8 LT 32 -> HORA = 3:23
# No. = MZ. 04, LT. 17 -> HORA = 18:05
# No. = 31 A -> HORA = 16:00 A 19:00
# No. = 15 LT. 38, MZ-838 -> HORA = 23:00 A 05:15
# No. = 613 -> HORA = 19:35
# No. = MZ. 75, LT. 11 -> HORA = 21:00
# No. = 834 -> HORA = 18:05
# No. = MZ. 21, LT. 11 -> HORA = 20:27
# No. = MZ-36, LT-20 -> HORA = 21:38
# No. = FRENTE AL NO. 20 -> HORA = 13:20
# No. = MZ. 32, LT. 4 -> HORA = 17:48
# No. = FRENTE AL NO. 38 -> HORA = 23:15
# No. = MZ. 71, LT. 1 -> HORA = 19:20
# No. = MZ. 137, LT. 3 -> HORA = 11:06
# No. = 637 -> HORA = 16:05
# No. = MZ. 139, LT. 16 -> HORA = 14:30
# No. = MZ. 3, LT. 32 -> HORA = 14:00
# No. = LOTE 11 -> HORA = 7:48
# No. = S/N -> HORA = 23:00 A 06:00
# No. = 522 -> HORA = 10:55
# No. = 442 -> HORA = 12:00
# No. = EDF. 78B -> HORA = 19:15
# No. = 405 -> HORA = 12:10
# No. = 758 -> HORA = 11:10 A 11:30
# No. = 692 -> HORA = 14:45
# No. = MZ-20, LT-14 -> HORA = 16:00 A 16:20
# No. = 845 -> HORA = 22:30
# No. = MZ. 4 LT. 1 -> HORA = 13:11
# No. = 564 -> HORA = 21:33
# No. = LT 10 MZ 143 -> HORA = 22:05
# No. = MZ. 28 LT. 77 -> HORA = 22:42
# No. = MZ-4, LT-58 -> HORA = 22:30
# No. = MZ. 212 LT. 19 -> HORA = 12:00 A 12:40
# No. = 43 INT. 4 -> HORA = 10:05
# No. = MZ-36, LT-26 -> HORA = 21:10
# No. = 719 -> HORA = 21:35
# No. = MZ-5, LT-4 -> HORA = 23:30 A 07:30
# No. = 728 -> HORA = 16:15 A 16:40
# No. = 437 -> HORA = 23:30 A 07:00
# No. = MZ-35, LT-3 -> HORA = 00:00 A 03:30
# No. = MZ. 18 LT. 19-A -> HORA = 13:00
# No. = 595 -> HORA = 20:30
# No. = 486 -> HORA = 12:30
# No. = MZ.1 B2 LT 37 -> HORA = 05:30 A 06:00
# No. = 94B -> HORA = 22:00 A 04:00
# No. = 801 -> HORA = 4:00
# No. = MZ-29, LT- 23 -> HORA = 20:40 A 22:00
# No. = 621 -> HORA = 19:00
# No. = 55 INT 1 -> HORA = 21:25
# No. = MZ-20, LT-3 -> HORA = 20:00
# No. = MZ 1 LT 35 -> HORA = 23:30
# No. = LT. 32 -> HORA = 22:15
# No. = 77 B INT 104 -> HORA = 22:30
# No. = MZ-3 -> HORA = 23:30
# No. = NP -> HORA = 15:30
# No. = 2-D -> HORA = 6:50
# No. = MZ. 12, LT. 71 -> HORA = 22:42
# No. = 674 -> HORA = 17:06
# No. = MZ. 16, LT. 1-A -> HORA = 20:25
# No. = 807 -> HORA = 22:00
# No. = 34-A -> HORA = 19:20
# No. = 11, DEPTO. 4 -> HORA = 22:00
# No. = 27-B -> HORA = 14:18
# No. = LT. 10, MZ. B -> HORA = 12:30
# No. = 55 INT. 4 -> HORA = 19:41
# No. = 6, INT. 2 -> HORA = 17:30 A 18:00
# No. = MZ-13, LT- 21 -> HORA = 23:55
# No. = 455 -> HORA = 04:00 A 05:00
# No. = MZ-14, LT- 9B -> HORA = 6:30
# No. = MZ. 77, LT.22 -> HORA = 15:45
# No. = 3-A -> HORA = 13:45
# No. = MZ. 130 -> HORA = 14:56
# No. = 773 -> HORA = 12:55
# No. = MZ-4, LT-17 -> HORA = 20:30
# No. = MZ-45, LT-8 -> HORA = 19:00 A 08:00
# No. = MZ-5, LT-15 -> HORA = 09:00 A 13:30
# No. = 466 -> HORA = 13:30 A 14:00
# No. = MZ-14, LT-12 -> HORA = 21:58
# No. = 219A -> HORA = 21:30
# No. = LT-1, MZ-83 -> HORA = 22:32
# No. = MZ-9, LT-24 -> HORA = 11:00 A 18:30
# No. = MZ-47, LT-13 -> HORA = 00:00 A 07:00
# No. = MZ-8 LT-36 C-1 -> HORA = 19:30
# No. = MZ. 2-B, LT. 52 -> HORA = 14:30
# No. = 51 INT. 2 -> HORA = 10:20
# No. = MZ. 114, LT. 10 -> HORA = 17:36
# No. = 864 -> HORA = 23:00
# No. = MZ. 67, LT. 2 -> HORA = 8:06
# No. = 532 -> HORA = 0:30
# No. = 827 -> HORA = 16:40
# No. = 39-C -> HORA = 19:33
# No. = LT. 37 MZ. 818 -> HORA = 17:48
# No. = 107-B -> HORA = 13:45
# No. = MAZDA. 85 LT. 10 -> HORA = 19:25
# No. = MZ. 38, LT. 1 DEPTO 8 -> HORA = 18:45
# No. = MZ. 17 -> HORA = 14:00
# No. = 3-B -> HORA = 12:10
# No. = MZ. 48 -> HORA = 3:38
# No. = MZ. 28, LT. 34 -> HORA = 11:57
# No. = MZ. 12 LT. B -> HORA = 8:48
# No. = MZ. 20, LT. 33 -> HORA = 14:00
# No. = MZ. 18 LT. 27 -> HORA = 16:30
# No. = MZ. 6 LT. 6 -> HORA = 0:21
# No. = 587 -> HORA = 10:40
# No. = MZ 134 LT20 -> HORA = 10:40
# No. = 753 -> HORA = 19:00
# No. = 76-B -> HORA = 20:10
# No. = EDIF. 78B INT. 304 -> HORA = 14:00
# No. = No. 94 INT. 2 -> HORA = 14:40
# No. = MZ. 2, LT. 32 -> HORA = 12:00
# No. = LT. 1 -> HORA = 3:45
# No. = 116-A INT. 17 -> HORA = 12:00
# No. = MZ. 22 LT. 8 -> HORA = 9:30
# No. = MZ-17, LT-29 -> HORA = 3:30
# No. = 2B -> HORA = 1:00
# No. = MZ-5, LT-66-1 -> HORA = 12:00 A 18:40
# No. = 10-A -> HORA = 18:15
# No. = MZ-118, LT- 12 -> HORA = 22:00 A 23:55
# No. = 7-B -> HORA = 18:50
# No. = 333A -> HORA = 21:15
# No. = 726 -> HORA = 08:45 A 10:15
# No. = MZ-14, LT-49 -> HORA = 23:00 A 08:00
# No. = MZ-35, LT-32 -> HORA = 15:30 A 18:00
# No. = MZ. 15 LT. 143 -> HORA = 18:00
# No. = 67 INT. 3 -> HORA = 23:40
# No. = EDIF. 78-B -> HORA = 12:43
# No. = 765 -> HORA = 22:23
# No. = MZ. 5, LT. 66 -> HORA = 18:15
# No. = MZ. 829 LT. 54 -> HORA = 18:10
# No. = 58-B -> HORA = 4:15
# No. = 16 DEPTO. 1 -> HORA = 14:05
# No. = 645 DEPTO. 3 -> HORA = 20:00
# No. = 490 -> HORA = 13:10
# No. = 581 -> HORA = 21:45
# No. = MZ. 5 LT. 2 -> HORA = 23:53
# No. = FRENTE AL NO. 173 -> HORA = 22:30
# No. = FRENTE AL NO. 223 -> HORA = 10:20
# No. = MZ. 25 LT. 3 -> HORA = 22:50
# No. = CASA 10 -> HORA = 13:58
# No. = MZ. 25 LT  14 -> HORA = 16:30
# No. = MZ. 35 LT. 4 -> HORA = 11:45
# No. = 675 -> HORA = 1:15
# No. = 552 -> HORA = 23:30
# No. = 941 -> HORA = 10:40
# No. = 650 -> HORA = 7:00
# No. = 521 -> HORA = 18:20
# No. = 601 -> HORA = 8:20
# No. = 565 -> HORA = 6:00
# No. = MZ. 55 LT. 5 -> HORA = 12:40
# No. = 8  BIS -> HORA = 23:20
# No. = MZ. 10 LT. 15 -> HORA = 1:11
# No. = MZ. 5 EDIF. 21 -> HORA = 19:00 A 21:30
# No. = MZ-135, LT-18 -> HORA = 23:00 A 23:30
# No. = 891 -> HORA = 14:10
# No. = 128-B -> HORA = 18:31
# No. = 13- B -> HORA = 22:51
# No. = 250 INT. 7 -> HORA = 20:00
# No. = 457 -> HORA = 16:20
# No. = 37-B -> HORA = 16:45
# No. = CONDOMINIO 6 CASA 52 -> HORA = 5:30
# No. = MZ. 15 BIS -> HORA = 7:12
# No. = MZ. 28, LT. 29 -> HORA = 20:30
# No. = MZ. 823, LT. 4 -> HORA = 21:41
# No. = MZ. 13 LT. 20 -> HORA = 5:30
# No. = LT 12 MZA 143 -> HORA = 22:30 A 02:50
# No. = MZ. 6 LT. 8 -> HORA = 16:30 A 20:00
# No. = 474 -> HORA = 23:00 A 01:47
# No. = 31 BIS -> HORA = 16:00
# No. = 458 A -> HORA = 5:30
# No. = MZ-19, LT-79 -> HORA = 23:00 A 06:00
# No. = MZ108 LT 7 -> HORA = 21:30 A 22:00
# No. = MZ-15, LT-57 -> HORA = 22:00 A 07:00
# No. = MZ-29, LT-19 -> HORA = 19:30
# No. = 700 -> HORA = 3:00
# No. = LT-1, MZ-6 -> HORA = 20:40
# No. = MZ.732 LT 95 -> HORA = 21:00 A 22:30
# No. = MZ19 LT 8 -> HORA = 01:00 A 04:30
# No. = 492 -> HORA = 21:10
# No. = MZ.17 LT.26 CASA .1 -> HORA = 20:50
# No. = EXT 9 INT 2 -> HORA = 20:00 A 21:30
# No. = NO 7 INT 4 -> HORA = 01:30 A 11:00
# No. = 495 -> HORA = 18:00 A 19:30
# No. = EDIF 77 -> HORA = 23:45
# No. = MZ-100, LT-7 -> HORA = 16:00 A 19:30
# No. = MZ 75B LT 3 -> HORA = 20:30
# No. = 467 -> HORA = 22:00
# No. = 92B -> HORA = 22:45
# No. = MZ-2, LT-43 -> HORA = 21:25
# No. = MZ-28, LT- 16 -> HORA = 15:30 A 18:00
# No. = EDIF-78 DEP-001 -> HORA = 23:00 A 07:00
# No. = MZA-10, LT- 13 -> HORA = 22:10
# No. = MZ-119, LT-4 -> HORA = 23:00 A 07:00
# No. = LT. 8 MZ. 2 A5 -> HORA = 17:00 A 18:30
# No. = MZA 49 LT 6 -> HORA = 23:00 A 12:00
# No. = MZ-39, LT-3 -> HORA = 00:30 A 05:30
# No. = LT-11, MZ-76 -> HORA = 18:30
# No. = MZ 37 LT 39 -> HORA = 05:00 A 07:00
# No. = MZ-150, LT-9 -> HORA = 9:15
# No. = MZ 4 A3 LT. 11 -> HORA = 18:30 A 05:00
# No. = 182 B -> HORA = 15:00 A 21:00
# No. = MZ 26 LT 47 -> HORA = 00:00 A 06:45
# No. = CASA 2 -> HORA = 19:30
# No. = MZ. 35 -> HORA = 18:15
# No. = 161 DEPTOS. 1 Y 2 -> HORA = 13:20
# No. = 767 -> HORA = 16:30
# No. = 539 -> HORA = 6:00
# No. = MZ. 7 LT. 11 -> HORA = 21:00
# No. = MZ. 55 , LT. 5 -> HORA = 18:18
# No. = MZ. 2 LT. 45 -> HORA = 5:50
# No. = MZ-36, LT-7 -> HORA = 22:00 A 05:00
# No. = MZ-28, LT-48 -> HORA = 22:45
# No. = 478B -> HORA = 13:00 A 13:30
# No. = 646 -> HORA = 19:30 A 19:40
# No. = MZ. 28 LT. 18 CASA 4 -> HORA = 14:55
# No. = MZ. 17, LT16 -> HORA = 15:00
# No. = MZ. 27, LT. 5 -> HORA = 5:00
# No. = 164 DEPTO 3 -> HORA = 14:03
# No. = 166 DEPTO. 1 -> HORA = 16:20
# No. = sab -> HORA = 18:40
# No. = 37- BIS -> HORA = 4:00
# No. = MZ.100 LT. 6 -> HORA = 13:40
# No. = MZ. 13 LT. 34 -> HORA = 12:40
# No. = MZ-829, LT- 31 -> HORA = 23:00
# No. = MZ101 LT 12 -> HORA = 6:50
# No. = 612 -> HORA = 23:30 A 00:00
# No. = 501 -> HORA = 21:00
# No. = MZ. 4 LT 1 -> HORA = 23:40
# No. = 40-A -> HORA = 17:00 A 20:05
# No. = EDIFICIO 77A DEPTO. -> HORA = 23:00 A 05:30
# No. = 3D -> HORA = 17:00
# No. = MZ-130, LT-6 -> HORA = 2:40
# No. = EDIF. 3 DEPARTAME -> HORA = 19:00 A 20:00
# No. = 515 -> HORA = 13:30 A 14:15
# No. = MZ. 30 LT. 8 -> HORA = 6:30
# No. = LT.  36 MZ.  818 -> HORA = 2:17
# No. = 572 -> HORA = 17:00
# No. = MZ. 133 -> HORA = 16:00
# No. = MZ. 24 LT. 46 -> HORA = 6:20
# No. = MZ.30 LT.8 -> HORA = 6:30
# ENTRE_CALLE_1 = PLAZA ANDA LUCIA -> HORA = 10:30 A 17:00
# ENTRE_CALLE_1 = PRADOS DE ROBLE -> HORA = 20:45
# ENTRE_CALLE_1 = LAGO CHAPULTEPEC -> HORA = 20:09
# ENTRE_CALLE_1 = AV ADOLFO LOPEZ MATEOS -> HORA = 6:51
# ENTRE_CALLE_1 = BOSQUES DE SUDAN -> HORA = 13:15
# ENTRE_CALLE_1 = PLAZUELA 1 -> HORA = 23:03
# ENTRE_CALLE_1 = VIRGEN NUESTRA SENORA DE LA L -> HORA = 15:00 A 17:00
# ENTRE_CALLE_1 = LAGUNA TERMINOS -> HORA = 8:45
# ENTRE_CALLE_1 = ORIENTE 10 -> HORA = 21:25
# ENTRE_CALLE_1 = FRANCISCO VILLA -> HORA = 1:45
# ENTRE_CALLE_1 = MANUEL ALTAMIRANO -> HORA = 19:00
# ENTRE_CALLE_1 = BOSQUES DE PAQUISTAN -> HORA = 19:40
# ENTRE_CALLE_1 = CALE 23 -> HORA = 13:50  A 14:0
# ENTRE_CALLE_1 = CUATLICHAN -> HORA = 22:30 A 23:00
# ENTRE_CALLE_1 = AV. CONSTITUCION DE LA REPUBL -> HORA = 6:50
# ENTRE_CALLE_1 = VALLE VOLGA -> HORA = 21:30
# ENTRE_CALLE_1 = PLAZA DE SESSAMO -> HORA = 20:19
# ENTRE_CALLE_1 = BOSQUES DE BONN -> HORA = 21:05
# ENTRE_CALLE_1 = 3ra AV -> HORA = 10:30 A 10.40
# ENTRE_CALLE_1 = PLAZAS DE SAN MARCOS -> HORA = 14:20
# ENTRE_CALLE_1 = RETORNO DE RABAT -> HORA = 21:25
# ENTRE_CALLE_1 = CERRRADA DE PANTITLAN -> HORA = 7:47
# ENTRE_CALLE_1 = PLAZUELA 5 -> HORA = 20:40
# ENTRE_CALLE_1 = ORIENTE 38 -> HORA = 16:50
# ENTRE_CALLE_1 = BOSQUES DE COLOMBIA -> HORA = 9:06
# ENTRE_CALLE_1 = MALITZIN -> HORA = 8:52
# ENTRE_CALLE_1 = VIRGEN DE LIMA -> HORA = 13:45 A 14:30
# ENTRE_CALLE_1 = BOSQUES DE LOS CONTINEN -> HORA = 5:00
# ENTRE_CALLE_1 = LAGO LA PIEDAD -> HORA = 16:20
# ENTRE_CALLE_1 = CERRADA DE TEXANITA -> HORA = 21:40
# ENTRE_CALLE_1 = SALVADOR DIAZ MIR -> HORA = 21:35
# ENTRE_CALLE_1 = CALLE 18B -> HORA = 19:20
# ENTRE_CALLE_1 = AV. PIRUL -> HORA = 5:30
# ENTRE_CALLE_1 = PLAZA DE SAN MARC -> HORA = 22:23
# ENTRE_CALLE_1 = AV.  PIRULES -> HORA = 18:20
# ENTRE_CALLE_1 = MADRUAGADA -> HORA = 10:40
# ENTRE_CALLE_1 = VALLE DE LAS CASA -> HORA = 23:00
# ENTRE_CALLE_1 = HACIENDA DE SAN M -> HORA = 22:45
# ENTRE_CALLE_1 = LAGO COLI -> HORA = 19:45
# ENTRE_CALLE_1 = HACIENDA DE GAVIA -> HORA = 5:00
# ENTRE_CALLE_1 = PONIENTE 24 -> HORA = 16:41
# ENTRE_CALLE_1 = AV. LAZARO CARDEN -> HORA = 09:00 A 16:00
# ENTRE_CALLE_1 = AV. VICENTE RIVA PALAC -> HORA = 18:30
# ENTRE_CALLE_1 = VIRGEN DE NUESTRA SANOR -> HORA = 19:45
# ENTRE_CALLE_1 = AV. FRANCISCO ZAR -> HORA = 12:00 A 12:30
# ENTRE_CALLE_1 = HACIENDA DE TORRE -> HORA = 9:20
# ENTRE_CALLE_1 = 7ma AVENID -> HORA = 23:00
# ENTRE_CALLE_1 = CASTILLO DE CHAPULTEPE -> HORA = 15:35
# ENTRE_CALLE_1 = VALLE DE LAS ZAPA -> HORA = 2:00
# ENTRE_CALLE_1 = 2. AV. -> HORA = 00:20  A 00:4
# ENTRE_CALLE_1 = FRANCISCO LAGO -> HORA = 20:00 A 00:00
# ENTRE_CALLE_1 = PLAZA DE LAS TRES -> HORA = 15:20
# ENTRE_CALLE_1 = ABASOLO -> HORA = 20:39
# ENTRE_CALLE_1 = BOSQUES DE SUIZA -> HORA = 22:10
# ENTRE_CALLE_1 = LAGO DEL FONDO -> HORA = 13:30 A 13:45
# ENTRE_CALLE_1 = AV. CANAL DE SALES -> HORA = 5:38
# ENTRE_CALLE_1 = PLAZA DE LA CONSTITUC -> HORA = 20:36
# ENTRE_CALLE_1 = VALLE DE CASTELBO -> HORA = 13:21
# ENTRE_CALLE_1 = BOSQUES DE LOS CONTINENTE -> HORA = 18:18
# ENTRE_CALLE_1 = HACIENDA DE MAYOR -> HORA = 05:00 A 00:00
# ENTRE_CALLE_1 = 6ta. AV -> HORA = 7:15
# ENTRE_CALLE_1 = ORQUIDEA -> HORA = 11:12
# ENTRE_CALLE_1 = AV. FRANCISCO VIL -> HORA = 19:30
# ENTRE_CALLE_1 = AV. DE LAS ZAPATA -> HORA = 12:00 A 13:00
# ENTRE_CALLE_1 = PALACIO DE GOBIER -> HORA = 19:10
# ENTRE_CALLE_1 = RIO DE LOS REMEDI -> HORA = 20:00 A 21:00
# ENTRE_CALLE_1 = RETORNO DE TIRANA -> HORA = 23:30
# ENTRE_CALLE_1 = LA ROSA -> HORA = 11:32
# ENTRE_CALLE_1 = GLORIETA DE BUCAR -> HORA = 09:15 A 09:30
# ENTRE_CALLE_1 = HACIENDA DE SAN A -> HORA = 5:45
# ENTRE_CALLE_1 = MONUMENTO A LA RE -> HORA = 18:30
# ENTRE_CALLE_1 = TONATZIN -> HORA = 19:00
# ENTRE_CALLE_1 = VILLA ALVARO OBRE -> HORA = 16:00
# ENTRE_CALLE_1 = LAGUNA DE TERMINO -> HORA = 8:00
# ENTRE_CALLE_1 = PRADOS DE AHUEHUETE -> HORA = 16:20
# ENTRE_CALLE_1 = VALLE DEL MAIZ -> HORA = 12:00
# ENTRE_CALLE_1 = ORIENTE 12 -> HORA = 13:50
# ENTRE_CALLE_1 = VALLE DEL DNIEPER -> HORA = 20:30 A 21:00
# ENTRE_CALLE_1 = GIRASOL -> HORA = 22:45 A 06:30
# ENTRE_CALLE_1 = LEON -> HORA = 19:20
# ENTRE_CALLE_1 = BOSQUES DE NIAMEY -> HORA = 16:25
# ENTRE_CALLE_1 = GUADALJARA -> HORA = 22:30
# ENTRE_CALLE_1 = AV. VICENTE RIVA PALACI -> HORA = 23:54
# ENTRE_CALLE_1 = LAGO PLAYA -> HORA = 20:20
# ENTRE_CALLE_1 = CUARTA AVENIDA -> HORA = 00:10 A 03:00
# ENTRE_CALLE_1 = ANGEL DE LA INDEPENDENCI -> HORA = 11:05
# ENTRE_CALLE_1 = HOMBRES  ILUSTRES -> HORA = 09:00 A 13:00
# ENTRE_CALLE_1 = HACIENDA DE RANCHO SE -> HORA = 21:00
# ENTRE_CALLE_1 = VALE DE MEXICO -> HORA = 14:10
# ENTRE_CALLE_1 = VIRGEN DE LA CONCEP -> HORA = 6:00
# ENTRE_CALLE_1 = LAGUNA DE SAN CRISTOB -> HORA = 03:00 A 05:15
# ENTRE_CALLE_1 = BAHIA DE HUATULCO -> HORA = 19:30 A 07:30
# ENTRE_CALLE_1 = BOSQUES DE LOS CONT -> HORA = 15:30
# ENTRE_CALLE_1 = AV. ADOLFO LOPEZ MATE -> HORA = 11:49
# ENTRE_CALLE_1 = BOSQUES DE LOS CONTIN -> HORA = 21:15
# ENTRE_CALLE_1 = VALLE DE MISSISSIPPI -> HORA = 15:10
# ENTRE_CALLE_1 = LAGUNA DE SAN CRIST -> HORA = 21:25
# ENTRE_CALLE_1 = AV. CUAHTEMOC -> HORA = 3:00
# ENTRE_CALLE_1 = BOSQUES DE LOS CONTINENT -> HORA = 23:30
# ENTRE_CALLE_1 = IGLESIA DE SANTO DOMI -> HORA = 01:00 A 06:30
# ENTRE_CALLE_1 = 6 AV. -> HORA = 22:30
# ENTRE_CALLE_1 = LAGNA DE TERMINOS -> HORA = 6:00
# ENTRE_CALLE_1 = SEBASTIAN LERDO DE TEJADA -> HORA = 9:50
# ENTRE_CALLE_1 = HACIENA DE LA NORIA -> HORA = 12:00
# ENTRE_CALLE_1 = MATLALCIHUATZIN -> HORA = 18:30
# ENTRE_CALLE_1 = LOS LAURELES -> HORA = 12:40
# ENTRE_CALLE_1 = BOSQUES DE MALASIA -> HORA = 21:20
# ENTRE_CALLE_1 = VIRGEN DE LA PAZ -> HORA = 21:40
# ENTRE_CALLE_1 = RTNO. DE BOSQUES DE PARIS -> HORA = 22:00
# ENTRE_CALLE_1 = 5 AV. -> HORA = 15:00 A 18:00
# ENTRE_CALLE_1 = ROSAS -> HORA = 21:43
# ENTRE_CALLE_1 = AV CIMALHUACAN -> HORA = 22:00-22:15
# ENTRE_CALLE_1 = HACIENDA  DE LA GAVIA -> HORA = 17:45 A18:20
# ENTRE_CALLE_1 = 1ra  AV. -> HORA = 8:30
# ENTRE_CALLE_1 = AURELIO RAMOS -> HORA = 17:00 A 18:00
# ENTRE_CALLE_1 = LUIS ECHEVERIIA -> HORA = 12:50 A 13:00
# ENTRE_CALLE_1 = PONIENTE 28 -> HORA = 11:55
# ENTRE_CALLE_1 = VIRGEN MARIA -> HORA = 12:00 A 12:40
# ENTRE_CALLE_1 = LAHO COLHUE -> HORA = 11:05
# ENTRE_CALLE_1 = AVENIDA 710 -> HORA = 17:10
# ENTRE_CALLE_1 = PLAZA. SAN JACINTO -> HORA = 21:50
# ENTRE_CALLE_1 = ROSARIO -> HORA = 21:00 A 01:50
# ENTRE_CALLE_1 = AV.  TEXCOCO -> HORA = 09:00 A 10:15
# ENTRE_CALLE_1 = CARLOS JONJITUD -> HORA = 15:48
# ENTRE_CALLE_1 = VALLE DE ZAMBEZI -> HORA = 08:00 A 11:05
# ENTRE_CALLE_1 = AV CARMELO PEREZ -> HORA = 21:50 A 22:10
# ENTRE_CALLE_1 = ANDADOR SN -> HORA = 13:30 A 13:35
# ENTRE_CALLE_1 = HACIENDA  DE PRESILLAS -> HORA = 4:25
# ENTRE_CALLE_1 = LAGO SEIS MILLONES -> HORA = 21:30
# ENTRE_CALLE_1 = JAVIER ROJO GOMEZ -> HORA = 14:30
# ENTRE_CALLE_1 = VALLE DEL MEZQUITAL -> HORA = 20:10
# ENTRE_CALLE_1 = VALLE DE AMECA -> HORA = 7:20
# ENTRE_CALLE_1 = HERMENEGILDO GALEANA -> HORA = 7:40
# ENTRE_CALLE_1 = BOSQUES DINAMARCA -> HORA = 22:30
# ENTRE_CALLE_1 = RETORNO DE ASMARA -> HORA = 22:40 A 06:40
# ENTRE_CALLE_1 = CONSTITUCION DE LA REPUBLICA -> HORA = 22:40 A 22:45
# ENTRE_CALLE_1 = CDA. DE ABANDONADO -> HORA = 12:30 A 13:00
# ENTRE_CALLE_1 = VALLE DE RHIERO -> HORA = 17:45 A 17:50
# ENTRE_CALLE_1 = 7ma.  AV. -> HORA = 16:40
# ENTRE_CALLE_1 = AV.  1 -> HORA = 21:15
# ENTRE_CALLE_1 = VIRGEN NUESTRA SENORA DE LA LUZ -> HORA = 21:55
# ENTRE_CALLE_1 = AMANCER RANCHERO -> HORA = 22:00 A 22:05
# ENTRE_CALLE_1 = BOSQUES  DE ARGELIA -> HORA = 18:40
# ENTRE_CALLE_1 = NUESTRA SRA. DE LOURDES -> HORA = 16:30 A 19:00
# ENTRE_CALLE_1 = HACIENDA DEL HERRADERO -> HORA = 14:10
# ENTRE_CALLE_1 = CAPIRO -> HORA = 0:00
# ENTRE_CALLE_1 = PONIENTE 26 -> HORA = 9:58
# ENTRE_CALLE_1 = FRANCISCO -> HORA = 13:40
# ENTRE_CALLE_1 = RTNO. BERBER -> HORA = 6:40
# ENTRE_CALLE_1 = PLAZUELA 3 DEL CARMEN -> HORA = 20:20 A 20:50
# ENTRE_CALLE_1 = BOSQUES ATENAS -> HORA = 21:40
# ENTRE_CALLE_1 = BOSQUES DE AMERICA -> HORA = 3:03
# ENTRE_CALLE_1 = BOSQUES DE VADUZ -> HORA = 23:10
# ENTRE_CALLE_1 = 4ta  AV. -> HORA = 22:00  A 08:00
# ENTRE_CALLE_1 = AV.  DE LAS ZAPATAS -> HORA = 7:45
# ENTRE_CALLE_1 = BOSQUES DE VARSOVIA -> HORA = 16:00 A 18:00
# ENTRE_CALLE_1 = BOSQUES DE CHINA -> HORA = 20:10
# ENTRE_CALLE_1 = MERIDA -> HORA = 0:10
# ENTRE_CALLE_1 = VIRGEN DE LOS REMEDIOS -> HORA = 0:50
# ENTRE_CALLE_1 = 7ma  AV. -> HORA = 09:00 A 09:30
# ENTRE_CALLE_1 = CDA. DE NINOS HEROES -> HORA = 19:20
# ENTRE_CALLE_1 = LITERATURA -> HORA = 17:37
# ENTRE_CALLE_1 = AV. DE RIO DE LOS REMEDIOS -> HORA = 6:50
# ENTRE_CALLE_1 = AGUILA NEGRA -> HORA = 19:00
# ENTRE_CALLE_1 = FELIPE CARRILLO PUERTO -> HORA = 16:06
# ENTRE_CALLE_1 = BOSQUES DE MASERUN -> HORA = 23:00
# ENTRE_CALLE_1 = ORIENTE 23 -> HORA = 14:05
# ENTRE_CALLE_1 = AV.CONTITUCION DE LA REPUBLICA -> HORA = 17:50 A 18:14
# ENTRE_CALLE_1 = CERRAD DE TEXANITA -> HORA = 12:59
# ENTRE_CALLE_1 = BOULEVAR DE LOS CONTINENTES -> HORA = 16:00
# ENTRE_CALLE_1 = LAGUNA DE ZEMPOALA -> HORA = 16:00 A 17:00
# ENTRE_CALLE_1 = BOSQUES DE MONACO -> HORA = 13:42
# ENTRE_CALLE_1 = BOULEVAR BOSQUES DE LAS NACIONES -> HORA = 9:52
# ...
# ENTRE_CALLE_2 = AV. CHIMLAHUACAN -> TURNO = 1
# ENTRE_CALLE_2 = MONTERREY -> TURNO = 3
# ENTRE_CALLE_2 = MANUEL GUTIERREZ NAJERA -> TURNO = 2
# ENTRE_CALLE_2 = AVIACION CIVIL -> TURNO = 1
# ENTRE_CALLE_2 = VALLE DE OAXACA -> TURNO = 2
# ENTRE_CALLE_2 = ZACATECAS -> TURNO = 1
# ENTRE_CALLE_2 = AVENIDA 1 -> TURNO = 2
# ENTRE_CALLE_2 = PONIENTE 19 -> TURNO = 3
# ENTRE_CALLE_2 = VAL SEQUILLO -> TURNO = 2
# ENTRE_CALLE_2 = DE VOLGA -> TURNO = 1
# ENTRE_CALLE_2 = VIRGEN DEL PERPETUO SOCORRO -> TURNO = 1
# ENTRE_CALLE_2 = PLAZA DE TLACOQUEMECATL -> TURNO = 3
# ENTRE_CALLE_2 = ARGELIA -> TURNO = 1
# ENTRE_CALLE_2 = DEL PASO -> TURNO = 2
# ENTRE_CALLE_2 = VALLE DE LAS SAMANZAS -> TURNO = 3
# ENTRE_CALLE_2 = CUATRO MILPAS -> TURNO = 2
# ENTRE_CALLE_2 = ABELARDO RODRIGUEZ -> TURNO = 3
# ENTRE_CALLE_2 = LAGO ZAIMA -> TURNO = 3
# ENTRE_CALLE_2 = PARQUES DEPORTIVOS -> TURNO = 1
# ENTRE_CALLE_2 = ANILLO PERIFERICO -> TURNO = 3
# ENTRE_CALLE_2 = VALLE  DE YANG TSE -> TURNO = 1
# ENTRE_CALLE_2 = BUCARELI -> TURNO = 1
# ENTRE_CALLE_2 = 3ra AVENIDA -> TURNO = 2
# ENTRE_CALLE_2 = PRADOS DE PIRULES -> TURNO = 3
# ENTRE_CALLE_2 = 7ma AV -> TURNO = 1
# ENTRE_CALLE_2 = VALLE  DEL YUKON -> TURNO = 3
# ENTRE_CALLE_2 = VIRGEN DE LA DOLOROSA -> TURNO = 2
# ENTRE_CALLE_2 = BENITO JUAREZ III -> TURNO = 1
# ENTRE_CALLE_2 = SULTEPEC -> TURNO = 3
# ENTRE_CALLE_2 = CIUDAD UNIVERSITARIA -> TURNO = 3
# ENTRE_CALLE_2 = CIENCIAS -> TURNO = 2
# ENTRE_CALLE_2 = HACIENDA DE SAN BERNABE -> TURNO = 2
# ENTRE_CALLE_2 = CALANDRIA -> TURNO = 2
# ENTRE_CALLE_2 = SAGRADO CORAZON -> TURNO = 1
# ENTRE_CALLE_2 = JACARANDA -> TURNO = 2
# ENTRE_CALLE_2 = LAGO ZIRAHUEN -> TURNO = 2
# ENTRE_CALLE_2 = PLAZAS DE SAN MARCOS -> TURNO = 3
# ENTRE_CALLE_2 = BOSQUES DE PAKISTAN -> TURNO = 3
# ENTRE_CALLE_2 = JOAQUINITA -> TURNO = 1
# ENTRE_CALLE_2 = VALLE DE YANG-TSE -> TURNO = 1
# ENTRE_CALLE_2 = LAGO ZUM -> TURNO = 2
# ENTRE_CALLE_2 = LAGO 4 MILLONES -> TURNO = 3
# ENTRE_CALLE_2 = TACUBA -> TURNO = 2
# ENTRE_CALLE_2 = PALACIO DE ITURBIDE -> TURNO = 2
# ENTRE_CALLE_2 = 6a. AV. -> TURNO = 1
# ENTRE_CALLE_2 = CANELOS -> TURNO = 3
# ENTRE_CALLE_2 = ORIENTE.8 -> TURNO = 3
# ENTRE_CALLE_2 = ORIENTE 18 -> TURNO = 2
# ENTRE_CALLE_2 = EFREN CARRILLO -> TURNO = 2
# ENTRE_CALLE_2 = MARIA BUSTILLOS -> TURNO = 3
# ENTRE_CALLE_2 = ADMINISTRADORES -> TURNO = 3
# ENTRE_CALLE_2 = VALLE DEL CARVAJAL -> TURNO = 3
# ENTRE_CALLE_2 = LAGO AULLAGAS -> TURNO = 3
# ENTRE_CALLE_2 = AGUSTIN DE ITURBIDE -> TURNO = 2
# ENTRE_CALLE_2 = LAGO TRASIMENO -> TURNO = 1
# ENTRE_CALLE_2 = LAGO LA DOGA -> TURNO = 3
# ENTRE_CALLE_2 = IGNACIO MATAMOROS -> TURNO = 3
# ENTRE_CALLE_2 = ORIENTE 17 -> TURNO = 2
# ENTRE_CALLE_2 = HDA DE LA GAVIA -> TURNO = 3
# ENTRE_CALLE_2 = 2da CDA DE FERROCARRIL -> TURNO = 1
# ENTRE_CALLE_2 = GUADALAJA -> TURNO = 3
# ENTRE_CALLE_2 = AV,TEXCOCO -> TURNO = 3
# ENTRE_CALLE_2 = VALLE DE LOS REYES -> TURNO = 1
# ENTRE_CALLE_2 = LA NORIA -> TURNO = 1
# ENTRE_CALLE_2 = LAGO VIETNA -> TURNO = 3
# ENTRE_CALLE_2 = VALLE DEL VOLGA -> TURNO = 3
# ENTRE_CALLE_2 = VICTORIA HUERTA -> TURNO = 3
# ENTRE_CALLE_2 = ROSARIO DOMINGUEZ -> TURNO = 3
# ENTRE_CALLE_2 = HACIENDA DE TOMACOCOS -> TURNO = 1
# ENTRE_CALLE_2 = AV. BORDO DE XOCIHACA -> TURNO = 1
# ENTRE_CALLE_2 = VIRGEN DEL SAGRADO CORZON DE JESUS -> TURNO = 3
# ENTRE_CALLE_2 = MATIN CARRERA -> TURNO = 3
# ENTRE_CALLE_2 = AV. PRIFERICO -> TURNO = 1
# ENTRE_CALLE_2 = LAGO CHALCO -> TURNO = 1
# ENTRE_CALLE_2 = VIRGEN DE GUADALUPE -> TURNO = 3
# ENTRE_CALLE_2 = ORIENTE 5 -> TURNO = 3
# ENTRE_CALLE_2 = LAGO ALBERTO -> TURNO = 3
# ENTRE_CALLE_2 = HACIENDA DE YECAPIXTLA -> TURNO = 2
# ENTRE_CALLE_2 = BOSQUES DE SUECIA -> TURNO = 3
# ENTRE_CALLE_2 = COLIMA -> TURNO = 1
# ENTRE_CALLE_2 = ANGEL DE LA INDEPENDENCIA -> TURNO = 3
# ENTRE_CALLE_2 = CIELITO LIDO -> TURNO = 2
# ENTRE_CALLE_2 = OTUMBA -> TURNO = 3
# ENTRE_CALLE_2 = AV. ZARCO -> TURNO = 1
# ENTRE_CALLE_2 = PONIENTE 24 -> TURNO = 3
# ENTRE_CALLE_2 = VICENTE VILLADA -> TURNO = 2
# ENTRE_CALLE_2 = VALLE DE MANZANEDO -> TURNO = 3
# ENTRE_CALLE_2 = ENRAMADA -> TURNO = 2
# ENTRE_CALLE_2 = VALLE DE ATEMAJAC -> TURNO = 1
# ENTRE_CALLE_2 = RETORNO DE ISLANDIA -> TURNO = 3
# ENTRE_CALLE_2 = PLAZA SAN PEDRO -> TURNO = 2
# ENTRE_CALLE_2 = TLALPAN -> TURNO = 1
# ENTRE_CALLE_2 = BOSQUES DE LOS CONTINETES -> TURNO = 3
# ENTRE_CALLE_2 = FLORES MAGON -> TURNO = 1
# ENTRE_CALLE_2 = MIGUEL NEGRETE -> TURNO = 3
# ENTRE_CALLE_2 = 4ta  A AV. -> TURNO = 3
# ENTRE_CALLE_2 = HACIENDAD DE LA GAVIA -> TURNO = 3
# ENTRE_CALLE_2 = VALLE  DE LA LUZ -> TURNO = 3
# ENTRE_CALLE_2 = BOSQUES DE NAIROBI -> TURNO = 1
# ENTRE_CALLE_2 = RTNO DE LUZACKA -> TURNO = 1
# ENTRE_CALLE_2 = VALLE DE PUEBLA -> TURNO = 2
# ENTRE_CALLE_2 = PROLONGACION LAZARO CARDENAS -> TURNO = 1
# ENTRE_CALLE_2 = ATLAPULCO -> TURNO = 1
# ENTRE_CALLE_2 = PETROLEOS -> TURNO = 1
# ENTRE_CALLE_2 = VALLE DE CHALCO -> TURNO = 2
# ENTRE_CALLE_2 = GLORETA DE PETROLEOS -> TURNO = 3
# ENTRE_CALLE_2 = CDA. DE XOCHIACA -> TURNO = 2
# ENTRE_CALLE_2 = URUAPAN -> TURNO = 3
# ENTRE_CALLE_2 = TEPEYAC -> TURNO = 2
# ENTRE_CALLE_2 = NUESTRA SENORA DE LA LUZ -> TURNO = 1
# ENTRE_CALLE_2 = 8va AVENIDA -> TURNO = 1
# ENTRE_CALLE_2 = GLADIOLA -> TURNO = 1
# ENTRE_CALLE_2 = AV. SOR JUAN I. DE LA CRUZ -> TURNO = 3
# ENTRE_CALLE_2 = LAGUNA DE SAN CR -> TURNO = 3
# ENTRE_CALLE_2 = BOSQUES DE LAS N -> TURNO = 3
# ENTRE_CALLE_2 = GLORIETA DE PETR -> TURNO = 2
# ENTRE_CALLE_2 = CORRIDO DEL NORT -> TURNO = 3
# ENTRE_CALLE_2 = RETORNO DE NAIRO -> TURNO = 2
# ENTRE_CALLE_2 = VIRGEN DEL SAGRA -> TURNO = 2
# ENTRE_CALLE_2 = IGNACIO LOPEZ RA -> TURNO = 3
# ENTRE_CALLE_2 = VALLE DE MIXTECO -> TURNO = 1
# ENTRE_CALLE_2 = COTIJA -> TURNO = 2
# ENTRE_CALLE_2 = JOSEFA ORTIZ DE DOMINGUE -> TURNO = 3
# ENTRE_CALLE_2 = SINFON -> TURNO = 1
# ENTRE_CALLE_2 = VALLE DE YUCON -> TURNO = 3
# ENTRE_CALLE_2 = PONIENTE 15 -> TURNO = 3
# ENTRE_CALLE_2 = LAGUNA DE ZEMPOALA -> TURNO = 2
# ENTRE_CALLE_2 = RIO DE LO REMEDIOS -> TURNO = 1
# ENTRE_CALLE_2 = RTNO. DE MASERU -> TURNO = 1
# ENTRE_CALLE_2 = VALLE DE COLORADO -> TURNO = 2
# ENTRE_CALLE_2 = SAN MATEO -> TURNO = 1
# ENTRE_CALLE_2 = 15 DE SEPTIEMBRE -> TURNO = 1
# ENTRE_CALLE_2 = FLORIPONDIO -> TURNO = 3
# ENTRE_CALLE_2 = VALLE DE HUALLAGA -> TURNO = 1
# ENTRE_CALLE_2 = EJE 4 -> TURNO = 2
# ENTRE_CALLE_2 = INDIOS VERDES -> TURNO = 2
# ENTRE_CALLE_2 = AVENIDA 5 -> TURNO = 3
# ENTRE_CALLE_2 = ORTOGRAFIA -> TURNO = 3
# ENTRE_CALLE_2 = ISABELES -> TURNO = 3
# ENTRE_CALLE_2 = VALLE DE MENA -> TURNO = 2
# ENTRE_CALLE_2 = CUERNAVACA -> TURNO = 1
# ENTRE_CALLE_2 = 7maAV -> TURNO = 3
# ENTRE_CALLE_2 = RAYANDO EL SOL -> TURNO = 2
# ENTRE_CALLE_2 = ROSAS -> TURNO = 2
# ENTRE_CALLE_2 = LAGO ATABASCA -> TURNO = 1
# ENTRE_CALLE_2 = AV. SALVADOR ALLENDE -> TURNO = 2
# ENTRE_CALLE_2 = PLAZA DEL CARMEN -> TURNO = 2
# ENTRE_CALLE_2 = LA TEXANITA -> TURNO = 1
# ENTRE_CALLE_2 = LIRIO -> TURNO = 3
# ENTRE_CALLE_2 = VALLE DE ZAMANSAS -> TURNO = 2
# ENTRE_CALLE_2 = PLAZUELA 19 -> TURNO = 1
# ENTRE_CALLE_2 = RIO BLANCO -> TURNO = 1
# ENTRE_CALLE_2 = CDA. DE PORFIRIO DIAZ -> TURNO = 3
# ENTRE_CALLE_2 = AZUCENA -> TURNO = 2
# ENTRE_CALLE_2 = PRADOS ALAMO -> TURNO = 1
# ENTRE_CALLE_2 = VALLE  DE YAKI -> TURNO = 2
# ENTRE_CALLE_2 = LAS ISABELES -> TURNO = 3
# ENTRE_CALLE_2 = VALLE COLORADO -> TURNO = 3
# ENTRE_CALLE_2 = CHURUBUSCO -> TURNO = 1
# ENTRE_CALLE_2 = CDA PRIMAVERA -> TURNO = 1
# ENTRE_CALLE_2 = JOSEFA ORTIZ DE DOMINGUEZ -> TURNO = 3
# ENTRE_CALLE_2 = HACIENDA DE SAN AGUSTIN -> TURNO = 2
# ENTRE_CALLE_2 = CALLEJON DE PRIMAVERA -> TURNO = 1
# ENTRE_CALLE_2 = CALLE 33 -> TURNO = 1
# ENTRE_CALLE_2 = PANCHITA -> TURNO = 3
# ENTRE_CALLE_2 = COCHERAS -> TURNO = 2
# ENTRE_CALLE_2 = CHAPARRITA -> TURNO = 2
# ENTRE_CALLE_2 = HACIENDA DE LA ESCONDIDA -> TURNO = 1
# ENTRE_CALLE_2 = SIUR 2 -> TURNO = 3
# ENTRE_CALLE_2 = HACIENDA DE ENEMEDIO -> TURNO = 1
# ENTRE_CALLE_2 = MAYRAN -> TURNO = 2
# ENTRE_CALLE_2 = HACIENDA DE MAYORAZGO -> TURNO = 3
# ENTRE_CALLE_2 = 5ta AVENIDA -> TURNO = 2
# ENTRE_CALLE_2 = CIPRES -> TURNO = 1
# ENTRE_CALLE_2 = JUAN COLORADO -> TURNO = 1
# ENTRE_CALLE_2 = BOSQUES DE ESPENA -> TURNO = 1
# ENTRE_CALLE_2 = BOULEVAR DE PRADOS DE ARAGON -> TURNO = 2
# ENTRE_CALLE_2 = JOSE BUSTILLO -> TURNO = 2
# ENTRE_CALLE_2 = AV. AMANECER RANCHERO -> TURNO = 3
# ENTRE_CALLE_2 = PRADOS DE ACACIA -> TURNO = 1
# ENTRE_CALLE_2 = SICOMOROS -> TURNO = 3
# ENTRE_CALLE_2 = GUERRERO -> TURNO = 2
# ENTRE_CALLE_2 = ORGANILLERO -> TURNO = 1
# ENTRE_CALLE_2 = CALLLE 18 -> TURNO = 1
# ENTRE_CALLE_2 = PONIENTE 9 -> TURNO = 3
# ENTRE_CALLE_2 = AV DE LAS TORRES -> TURNO = 1
# ENTRE_CALLE_2 = NIAMEY -> TURNO = 2
# ENTRE_CALLE_2 = LAGUNA  DE TERMINOS -> TURNO = 2
# ENTRE_CALLE_2 = AV.  CHIMALHUACAN -> TURNO = 1
# ENTRE_CALLE_2 = AV.  ADOLFO LOPEZ MATEOS -> TURNO = 2
# ENTRE_CALLE_2 = BOSQUES DE IRAK -> TURNO = 3
# ENTRE_CALLE_2 = MALINALCIO -> TURNO = 1
# ENTRE_CALLE_2 = LA NORTENA -> TURNO = 1
# ENTRE_CALLE_2 = JIMENEZ CANTU -> TURNO = 1
# ENTRE_CALLE_2 = ORIENTE. 24 -> TURNO = 3
# ENTRE_CALLE_2 = JOAQUINTA -> TURNO = 1
# ENTRE_CALLE_2 = MICHOACANA -> TURNO = 2
# ENTRE_CALLE_2 = LAGUNA DEL CARMEN -> TURNO = 1
# ENTRE_CALLE_2 = ORIENTE 33 -> TURNO = 1
# ENTRE_CALLE_2 = LA ROSA -> TURNO = 1
# ENTRE_CALLE_2 = 2A AV -> TURNO = 3
# ENTRE_CALLE_2 = 1a. AVENIDA -> TURNO = 1
# ENTRE_CALLE_2 = BOSQUES DE MONGOLIA -> TURNO = 3
# ENTRE_CALLE_2 = LAGO ETHER -> TURNO = 1
# ENTRE_CALLE_2 = DR. GUSTAVO BAZ -> TURNO = 3
# ENTRE_CALLE_2 = HOMBRES ILUSTRES -> TURNO = 2
# ENTRE_CALLE_2 = VALLE DE ZAMBESZI -> TURNO = 1
# ENTRE_CALLE_2 = VIRGE DE NUESTRA SENORA DE LA LUZ -> TURNO = 3
# ENTRE_CALLE_2 = LAGO ZUMPAGO -> TURNO = 1
# ENTRE_CALLE_2 = CDA DE ESCONDIDA -> TURNO = 2
# ENTRE_CALLE_2 = VALLE DE BALDEBEZANA -> TURNO = 3
# ENTRE_CALLE_2 = HUIXQUILICAN -> TURNO = 3
# ENTRE_CALLE_2 = PERIFERICO -> TURNO = 1
# ENTRE_CALLE_2 = RANCHO SECO -> TURNO = 2
# ENTRE_CALLE_2 = MACORINA -> TURNO = 2
# ENTRE_CALLE_2 = COSTENAS -> TURNO = 1
# ENTRE_CALLE_2 = HACIENDA DE SOLIS -> TURNO = 1
# ENTRE_CALLE_2 = SANCHEZ COLIN -> TURNO = 1
# ENTRE_CALLE_2 = CARLOS LONGITUD -> TURNO = 2
# ENTRE_CALLE_2 = BOSQUES DE FRANCIA -> TURNO = 1
# ENTRE_CALLE_2 = ZIHUATANEJO -> TURNO = 2
# ENTRE_CALLE_2 = 703 -> TURNO = 2
# ENTRE_CALLE_2 = CAMA DE PIEDRAS -> TURNO = 1
# ENTRE_CALLE_2 = BOSQUES DE ECUADOR -> TURNO = 1
# ENTRE_CALLE_2 = VALLE  DE BRAVO -> TURNO = 1
# ENTRE_CALLE_2 = HACIENDA DE ZOTOLUCA -> TURNO = 2
# ENTRE_CALLE_2 = ORIENTE 7 -> TURNO = 2
# ENTRE_CALLE_2 = GALEANA -> TURNO = 1
# ENTRE_CALLE_2 = VALLE  DE VISTULA -> TURNO = 1
# ENTRE_CALLE_2 = HUITZILOPOCHTLI -> TURNO = 2
# ENTRE_CALLE_2 = BOSQUES  DE IRAK -> TURNO = 3
# ENTRE_CALLE_2 = ORIENTE 41 -> TURNO = 3
# ENTRE_CALLE_2 = PONIENTE 13 -> TURNO = 3
# ENTRE_CALLE_2 = NORTE 4 -> TURNO = 2
# ENTRE_CALLE_2 = AV. FRACISCO VILLA -> TURNO = 3
# ENTRE_CALLE_2 = VALLE DE SAN JUAN -> TURNO = 2
# ENTRE_CALLE_2 = GUILLERMO AGUIRRE FIERRO -> TURNO = 1
# ENTRE_CALLE_2 = HACIENDADA DE SOLIS -> TURNO = 2
# ENTRE_CALLE_2 = RIVA PALACIO -> TURNO = 3
# ENTRE_CALLE_2 = CERRADA DE CASTILLA -> TURNO = 2
# ENTRE_CALLE_2 = 6ta. AV. -> TURNO = 3
# ENTRE_CALLE_2 = BOSQUES DE IRLANDA -> TURNO = 1
# ENTRE_CALLE_2 = PRADOS DE CIPRES -> TURNO = 3
# ENTRE_CALLE_2 = AV. PLAZAS DE ARAGON -> TURNO = 1
# ENTRE_CALLE_2 = CERRADA DE XOCHITENCO -> TURNO = 3
# ENTRE_CALLE_2 = HACIENDA DE SAN MATEO -> TURNO = 3
# ENTRE_CALLE_2 = CALLEJON PRIMAVERA -> TURNO = 1
# ENTRE_CALLE_2 = EMIIANO ZAPATA -> TURNO = 1
# ENTRE_CALLE_2 = VALLE DEL MAIZ -> TURNO = 3
# ENTRE_CALLE_2 = PROGRESONACIONAL -> TURNO = 3
# ENTRE_CALLE_2 = AV ZARCO -> TURNO = 2
# ENTRE_CALLE_2 = VALLE  DEL YANG TSE -> TURNO = 1
# ENTRE_CALLE_2 = 14 -> TURNO = 1
# ENTRE_CALLE_2 = VALLE  DE MEXICO -> TURNO = 3
# ENTRE_CALLE_2 = AV MORELIA -> TURNO = 1
# ENTRE_CALLE_2 = GLORITA DE COLON -> TURNO = 1
# ENTRE_CALLE_2 = GTA DE PETROLEOS -> TURNO = 3
# ENTRE_CALLE_2 = RICARDO FLORES MAGON -> TURNO = 3
# ENTRE_CALLE_2 = ARANDAS -> TURNO = 3
# ENTRE_CALLE_2 = CAFETAL -> TURNO = 3
# ENTRE_CALLE_2 = BOSQUES DE BATA -> TURNO = 1
# ENTRE_CALLE_2 = FERROCARIL -> TURNO = 2
# ENTRE_CALLE_2 = PLAZA DE SAN PEDRO -> TURNO = 3
# ENTRE_CALLE_2 = ETICA -> TURNO = 2
# ENTRE_CALLE_2 = LAGO CHAIREL -> TURNO = 1
# ENTRE_CALLE_2 = LAGO XOCHIMILCO -> TURNO = 3
# ENTRE_CALLE_2 = GUDALUPE VICTORIA -> TURNO = 3
# ENTRE_CALLE_2 = PROLONGACION 4A AVENIDA -> TURNO = 2
# ENTRE_CALLE_2 = IZTACIHUALTL -> TURNO = 3
# ENTRE_CALLE_2 = PAZA DEL ESTUDIANTE -> TURNO = 1
# ENTRE_CALLE_2 = CALLE 20 -> TURNO = 1
# ENTRE_CALLE_2 = LAGO ZUMPANGO -> TURNO = 2
# ENTRE_CALLE_2 = CHILPANCINGO -> TURNO = 1
# ENTRE_CALLE_2 = AV.  PANTITLAN -> TURNO = 2
# ENTRE_CALLE_2 = NORTE. 1 -> TURNO = 3
# ENTRE_CALLE_2 = AV CHIMALHUACAN -> TURNO = 1
# ENTRE_CALLE_2 = LA PANCHITA -> TURNO = 1
# ENTRE_CALLE_2 = AV.5 -> TURNO = 2
# ENTRE_CALLE_2 = AV 3 -> TURNO = 2
# ENTRE_CALLE_2 = 6TA. AV. -> TURNO = 1
# ENTRE_CALLE_2 = AV. SAN ANGEL -> TURNO = 2
# ENTRE_CALLE_2 = PLAZA DE LA LUZ -> TURNO = 3
# ENTRE_CALLE_2 = PLAZA DE SAN MARCOS -> TURNO = 2
# ENTRE_CALLE_2 = LATERAL DE LA AV, BORDO DE XOCHIACA -> TURNO = 2
# ENTRE_CALLE_2 = SAN LUIS POTOSI -> TURNO = 3
# ENTRE_CALLE_2 = 7A AVENIDA -> TURNO = 2
# ENTRE_CALLE_2 = 4A AVENIDA -> TURNO = 2
# ENTRE_CALLE_2 = SAN LORENZO -> TURNO = 3
# ENTRE_CALLE_2 = VALLA DE LAS ZAPATAS -> TURNO = 3
# ENTRE_CALLE_2 = MANUEL MARIA CONTERAS -> TURNO = 2
# ENTRE_CALLE_2 = SAN MARQUENA -> TURNO = 3
# ENTRE_CALLE_2 = ILHUICAMINA -> TURNO = 1
# ENTRE_CALLE_2 = VALLE DEL CONGO -> TURNO = 1
# ENTRE_CALLE_2 = XINACANTECATL -> TURNO = 3
# ENTRE_CALLE_2 = SIFONN -> TURNO = 2
# ENTRE_CALLE_2 = 6A AVENIDA -> TURNO = 3
# ENTRE_CALLE_2 = AVENIDA 6 B -> TURNO = 1
# ENTRE_CALLE_2 = DOS ARBOLITOS -> TURNO = 1
# ENTRE_CALLE_2 = LAGO SAN PEDRO -> TURNO = 1
# ENTRE_CALLE_2 = AGUASCALIENTES -> TURNO = 2
# ENTRE_CALLE_2 = AV FERROCARRIL -> TURNO = 2
# ENTRE_CALLE_2 = FUENTE DE DIANA -> TURNO = 1
# ENTRE_CALLE_2 = CAMA DE PEIDRA -> TURNO = 3
# ENTRE_CALLE_2 = CIELLITO LINDO -> TURNO = 2
# ENTRE_CALLE_2 = CDA DE SOLIS -> TURNO = 2
# ENTRE_CALLE_2 = VALLE DEL YANG STE -> TURNO = 2
# ENTRE_CALLE_2 = TEPIC -> TURNO = 2
# ENTRE_CALLE_2 = BOSQUES DE SUDAN -> TURNO = 1
# ENTRE_CALLE_2 = LAGO LAGO CARDIEL -> TURNO = 1
# ENTRE_CALLE_2 = VALLE DE BARDAJI -> TURNO = 3
# ENTRE_CALLE_2 = BOSQUES DE BELGICA -> TURNO = 2
# ENTRE_CALLE_2 = IGNACIO ZARAGOZA -> TURNO = 3
# ENTRE_CALLE_2 = LAGO WETTER -> TURNO = 3
# ENTRE_CALLE_2 = VILLA DE GUERRERO -> TURNO = 2
# ENTRE_CALLE_2 = CICLAMORES -> TURNO = 3
# ENTRE_CALLE_2 = PLUTARCO ELIAS CALLES -> TURNO = 3
# ENTRE_CALLE_2 = CHIHUAHUA -> TURNO = 1
# ENTRE_CALLE_2 = BOULEVARD BOSQUES DE AFRICA -> TURNO = 1
# ENTRE_CALLE_2 = PAJARERA -> TURNO = 2
# ENTRE_CALLE_2 = 2A AVENIDA -> TURNO = 3
# ENTRE_CALLE_2 = 4A. AVENIDA -> TURNO = 3
# COLONIA = VALLE DE ARAGON 1RA SECCION -> TURNO = 3
# COLONIA = TAMAULIPAS EL PALMAR -> TURNO = 1
# COLONIA = TAMAULIPAS -> TURNO = 2
# COLONIA = BENITO JUAREZ 3a SECCION -> TURNO = 2
# COLONIA = AMPLACION VICENTE VILLADA -> TURNO = 3
# COLONIA = APLIACION LAS AGUILAS -> TURNO = 1
# COLONIA = BENITO JUAZRE III -> TURNO = 3
# COLONIA = JARDINES DE GUAD -> TURNO = 3
# COLONIA = SAN AGUSTIN ATLA -> TURNO = 1
# COLONIA = METROPOLITANA 2da -> TURNO = 2
# COLONIA = TAMAULIPAS SECCION VIRGENCIT -> TURNO = 3
# COLONIA = TAMAULIPAS SECCION LAS FLORE -> TURNO = 3
# COLONIA = AMPLAICION VICENTE VILLADA -> TURNO = 2
# COLONIA = VALLE DE ARAGON 2a.SECCION -> TURNO = 1
# COLONIA = BENIOT JUAREZ III -> TURNO = 3
# COLONIA = TAMAULIPAS SECION EL PALMAR -> TURNO = 3
# COLONIA = LAS  PALMAS -> TURNO = 2
# COLONIA = BENITO JUARES 3a. SECCION -> TURNO = 3
# COLONIA = NEZAHULACOYOTL -> TURNO = 2
# COLONIA = LAPERLA -> TURNO = 2
# COLONIA = TAMAULIPAS SECICON LAS FLORES -> TURNO = 1
# COLONIA = AMPLIACION CIUDADA LAGO -> TURNO = 1
# COLONIA = EJIDOS DE SAN AGUSTIN -> TURNO = 3
# COLONIA = PARDOS DE ARAGON -> TURNO = 1
# COLONIA = UNIDAD IZCALLI NEZA -> TURNO = 3
# COLONIA = BENITO JAUREZ III -> TURNO = 3
# COLONIA = EL PORVENIR -> TURNO = 3
# COLONIA = AMPLIACION CUIDAD LAGO -> TURNO = 2
# COLONIA = EL S0L -> TURNO = 2
# COLONIA = BENITO JUAREZ  3a. SECCION -> TURNO = 3
# COLONIA = INDUSTRIAL IZCALLI -> TURNO = 2
# COLONIA = CAMPESTRE GUADALUPE -> TURNO = 3
# COLONIA = VALLE DE ARAGO 2da SECCION -> TURNO = 1
# COLONIA = METROPOLITANA -> TURNO = 1
# COLONIA = 6ta AVENIDA -> TURNO = 2
# COLONIA = BENITO JUAREZ 2da SECCION -> TURNO = 1
# COLONIA = CUIDAD LAGO -> TURNO = 3
# COLONIA = VALLE DE ARAGON I -> TURNO = 3
# COLONIA = TAMAUULIPAS SECCION VIRGENCITAS -> TURNO = 2
# COLONIA = UNIDAD ANTONIO ALZATE -> TURNO = 2
# COLONIA = BENITIO JUAREZ I -> TURNO = 2
# COLONIA = VALLE DE ARAGON II -> TURNO = 3
# COLONIA = ANTONIO ALZATE -> TURNO = 3
