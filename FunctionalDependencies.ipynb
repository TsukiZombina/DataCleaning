# %% [markdown]
# # Dependencias Funcionales

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Carga los datos del archivo .csv en un data frame de pandas.

# %%
df = pd.read_csv('InfoNeza/Delitos/Delitos_cleaned.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df = df.drop(columns = ['ID','X', 'Y', 'HORA_FIN'])

# %%
print(df.columns)
print(df.head(5))
# Out:
# Index(['HORA_INICIO', 'FECHA', 'MES', 'DELITO', 'CALLE', 'No.',
#        'ENTRE_CALLE_1', 'ENTRE_CALLE_2', 'COLONIA', 'SECTOR', 'CUADRANTE',
#        'TURNO'],
#       dtype='object')
#   HORA_INICIO       FECHA    MES            DELITO            CALLE      No.  \
# 0       22:30  2016-01-01  ENERO  ROBO DE VEHICULO  VALLE DE MEXICO  Sin No.
# 1        6:40  2016-01-01  ENERO  ROBO DE VEHICULO    RANCHO GRANDE  Sin No.
# 2       13:30  2016-01-01  ENERO  ROBO DE VEHICULO         LAURELES  Sin No.
# 3       03:00  2016-01-01  ENERO  ROBO DE VEHICULO    LAGO GRAN OSO       99
# 4       14:00  2016-01-01  ENERO  ROBO DE VEHICULO    LA CHAPARRITA  Sin No.
#
#        ENTRE_CALLE_1      ENTRE_CALLE_2                      COLONIA SECTOR  \
# 0  VALLE DE YANG TSE     VALLE DE YUKON  VALLE DE ARAGON 1ra SECCION    1.0
# 1  AV. CARMELO PEREZ  Sin ENTRE_CALLE_2            BENITO JUAREZ III   11.0
# 2      CIELITO LINDO  Sin ENTRE_CALLE_2             BENITO JUAREZ II   10.0
# 3        AV. PIRULES  Sin ENTRE_CALLE_2                    AGUA AZUL    9.0
# 4             4ta AV  AMANECER RANCHERO            BENITO JUAREZ III   11.0
#
#   CUADRANTE  TURNO
# 0      C013      1
# 1      C112      1
# 2      C108      2
# 3      C095      1
# 4      C116      2

# %% [markdown]
# ## Algoritmo de fuerza bruta para encontrar dependencias funcionales
#
# El siguiente algoritmo de fuerza bruta determina las dependencias funcionales dados un data frame y dos columnas $c_{1}$ y $c_{2}$.

# %%
def get_fd(df, c1, c2):
    for value in df[c2].unique():
        # Get all entries that contain 'value' in c2
        df_value = df[df[c2] == value]
        
        
        if len(df_value) > 1:
            # Check if all values in the column c1 are the same
            uniques = df_value[c1].unique()
            #print('Uniques of column {0} under {1} = {2}'.format(c1, c2, value))
            #print(len(uniques))
            
            if len(uniques) == 1:
                print('{0} = {1} -> {2} = {3}'.format(c2, value, c1, uniques[0]))
        

def search_fd(df):
    for c1 in df.columns:
        for c2 in df.columns:
            if c1 is not c2:
                get_fd(df, c1, c2)
                
search_fd(df)
# Out:
# CALLE = EX CONVENTO DE CHURUBU -> HORA_INICIO = 8:10
# CALLE = CARLOS HANK GONZALEZ -> HORA_INICIO = 12:00
# CALLE = BOSQUES DE GUINEA -> HORA_INICIO = 16:00
# No. = MZ-3 -> HORA_INICIO = 23:30
# ENTRE_CALLE_1 = BOSQUES DE LOS CONTINEN -> HORA_INICIO = 5:00
# ENTRE_CALLE_1 = TOPACIO -> HORA_INICIO = 23:25
# ENTRE_CALLE_1 = TLANEPANTLA -> HORA_INICIO = 18:35
# ENTRE_CALLE_2 = ORIENTE 12 -> HORA_INICIO = 0:19
# HORA_INICIO = 5:09 -> FECHA = 2016-05-30
# HORA_INICIO = 15:09 -> FECHA = 2016-08-27
# HORA_INICIO = 7:14 -> FECHA = 2017-07-14
# CALLE = LAGUA DE MAYRAN -> FECHA = 2016-09-01
# CALLE = EX CONVENTO DE CHURUBU -> FECHA = 2016-03-17
# CALLE = ENRIQUE GONZALEZ MARTINEZ -> FECHA = 2016-07-27
# CALLE = VALLE DE FARAONES -> FECHA = 2017-08-02
# No. = 171 BIS -> FECHA = 2016-10-06
# No. = MZ. 53 LT. 10 -> FECHA = 2016-06-26
# No. = MZ-3 -> FECHA = 2016-12-21
# No. = 461 -> FECHA = 2017-04-07
# ENTRE_CALLE_1 = BOSQUES DE LOS CONTINEN -> FECHA = 2016-02-02
# ENTRE_CALLE_1 = AV. CONTITUCION DE LA -> FECHA = 2016-03-29
# ENTRE_CALLE_1 = TLANEPANTLA -> FECHA = 2017-03-07
# ENTRE_CALLE_2 = CERRADA DE ESCONDI -> FECHA = 2016-03-14
# ENTRE_CALLE_2 = ORIENTE 12 -> FECHA = 2016-10-07
# ENTRE_CALLE_2 = IZTLACCIHUATL -> FECHA = 2017-01-15
# ENTRE_CALLE_2 = PLAZUELA 19 -> FECHA = 2017-08-04
# ENTRE_CALLE_2 = BOULEVARD BOSQUES DE AFRICA -> FECHA = 2017-09-26
# COLONIA = BENITO JAUREZ 1a. SECCION -> FECHA = 2017-07-06
# COLONIA = BENITO JUAREZ 2da SECCION -> FECHA = 2017-08-15
# HORA_INICIO = 7:22 -> MES = ENERO
# HORA_INICIO = 22:29 -> MES = ENERO
# HORA_INICIO = 0:18 -> MES = FEBRERO
# HORA_INICIO = 00:10 -> MES = MARZO
# HORA_INICIO = 23:37 -> MES = MARZO
# HORA_INICIO = 0:22 -> MES = ABRIL
# HORA_INICIO = 12:23 -> MES = MAYO
# HORA_INICIO = 5:09 -> MES = MAYO
# HORA_INICIO = 4:49 -> MES = JUNIO
# HORA_INICIO = 16:34 -> MES = JUNIO
# HORA_INICIO = 8:47 -> MES = JUNIO
# HORA_INICIO = 1:06 -> MES = JUNIO
# HORA_INICIO = 19:23 -> MES = JULIO
# HORA_INICIO = 11:38 -> MES = JULIO
# HORA_INICIO = 15:09 -> MES = AGOSTO
# HORA_INICIO = 1:23 -> MES = AGOSTO
# HORA_INICIO = 4:43 -> MES = SEPTIEMBRE
# HORA_INICIO = 21:32 -> MES = SEPTIEMBRE
# HORA_INICIO = 3:51 -> MES = SEPTIEMBRE
# HORA_INICIO = 18:38 -> MES = NOVIEMBRE
# HORA_INICIO = 23:48 -> MES = NOVIEMBRE
# HORA_INICIO = 2:33 -> MES = FEBRERO
# HORA_INICIO = 0:48 -> MES = ABRIL
# HORA_INICIO = 09:10 -> MES = FEBRERO
# HORA_INICIO = 7:14 -> MES = JULIO
# FECHA = 2016-01-01 -> MES = ENERO
# FECHA = 2016-02-01 -> MES = ENERO
# FECHA = 2016-03-01 -> MES = ENERO
# FECHA = 2016-04-01 -> MES = ENERO
# FECHA = 2016-05-01 -> MES = ENERO
# FECHA = 2016-06-01 -> MES = ENERO
# FECHA = 2016-07-01 -> MES = ENERO
# FECHA = 2016-08-01 -> MES = ENERO
# FECHA = 2016-09-01 -> MES = ENERO
# FECHA = 2016-10-01 -> MES = ENERO
# FECHA = 2016-11-01 -> MES = ENERO
# FECHA = 2016-12-01 -> MES = ENERO
# FECHA = 2016-01-13 -> MES = ENERO
# FECHA = 2016-01-14 -> MES = ENERO
# FECHA = 2016-01-15 -> MES = ENERO
# FECHA = 2016-01-16 -> MES = ENERO
# FECHA = 2016-01-17 -> MES = ENERO
# FECHA = 2016-01-18 -> MES = ENERO
# FECHA = 2016-01-19 -> MES = ENERO
# FECHA = 2016-01-20 -> MES = ENERO
# FECHA = 2016-01-21 -> MES = ENERO
# FECHA = 2016-01-22 -> MES = ENERO
# FECHA = 2016-01-23 -> MES = ENERO
# FECHA = 2016-01-24 -> MES = ENERO
# FECHA = 2016-01-25 -> MES = ENERO
# FECHA = 2016-01-26 -> MES = ENERO
# FECHA = 2016-01-27 -> MES = ENERO
# FECHA = 2016-01-28 -> MES = ENERO
# FECHA = 2016-01-29 -> MES = ENERO
# FECHA = 2016-01-30 -> MES = ENERO
# FECHA = 2016-01-31 -> MES = ENERO
# FECHA = 2016-01-02 -> MES = FEBRERO
# FECHA = 2016-02-02 -> MES = FEBRERO
# FECHA = 2016-03-02 -> MES = FEBRERO
# FECHA = 2016-04-02 -> MES = FEBRERO
# FECHA = 2016-05-02 -> MES = FEBRERO
# FECHA = 2016-06-02 -> MES = FEBRERO
# FECHA = 2016-07-02 -> MES = FEBRERO
# FECHA = 2016-08-02 -> MES = FEBRERO
# FECHA = 2016-09-02 -> MES = FEBRERO
# FECHA = 2016-10-02 -> MES = FEBRERO
# FECHA = 2016-11-02 -> MES = FEBRERO
# FECHA = 2016-12-02 -> MES = FEBRERO
# FECHA = 2016-02-13 -> MES = FEBRERO
# FECHA = 2016-02-14 -> MES = FEBRERO
# FECHA = 2016-02-15 -> MES = FEBRERO
# FECHA = 2016-02-16 -> MES = FEBRERO
# FECHA = 2016-02-17 -> MES = FEBRERO
# FECHA = 2016-02-18 -> MES = FEBRERO
# FECHA = 2016-02-19 -> MES = FEBRERO
# FECHA = 2016-02-20 -> MES = FEBRERO
# FECHA = 2016-02-21 -> MES = FEBRERO
# FECHA = 2016-02-22 -> MES = FEBRERO
# FECHA = 2016-02-23 -> MES = FEBRERO
# FECHA = 2016-02-24 -> MES = FEBRERO
# FECHA = 2016-02-25 -> MES = FEBRERO
# FECHA = 2016-02-26 -> MES = FEBRERO
# FECHA = 2016-02-27 -> MES = FEBRERO
# FECHA = 2016-02-28 -> MES = FEBRERO
# FECHA = 2016-02-29 -> MES = FEBRERO
# FECHA = 2016-01-03 -> MES = MARZO
# FECHA = 2016-02-03 -> MES = MARZO
# FECHA = 2016-03-03 -> MES = MARZO
# FECHA = 2016-04-03 -> MES = MARZO
# FECHA = 2016-05-03 -> MES = MARZO
# FECHA = 2016-06-03 -> MES = MARZO
# FECHA = 2016-07-03 -> MES = MARZO
# FECHA = 2016-08-03 -> MES = MARZO
# FECHA = 2016-09-03 -> MES = MARZO
# FECHA = 2016-10-03 -> MES = MARZO
# FECHA = 2016-11-03 -> MES = MARZO
# FECHA = 2016-12-03 -> MES = MARZO
# FECHA = 2016-03-13 -> MES = MARZO
# FECHA = 2016-03-14 -> MES = MARZO
# FECHA = 2016-03-15 -> MES = MARZO
# FECHA = 2016-03-16 -> MES = MARZO
# FECHA = 2016-03-17 -> MES = MARZO
# FECHA = 2016-03-18 -> MES = MARZO
# FECHA = 2016-03-19 -> MES = MARZO
# FECHA = 2016-03-20 -> MES = MARZO
# FECHA = 2016-03-21 -> MES = MARZO
# FECHA = 2016-03-22 -> MES = MARZO
# FECHA = 2016-03-23 -> MES = MARZO
# FECHA = 2016-03-24 -> MES = MARZO
# FECHA = 2016-03-25 -> MES = MARZO
# FECHA = 2016-03-26 -> MES = MARZO
# FECHA = 2016-03-27 -> MES = MARZO
# FECHA = 2016-03-28 -> MES = MARZO
# FECHA = 2016-03-29 -> MES = MARZO
# FECHA = 2016-03-30 -> MES = MARZO
# FECHA = 2016-03-31 -> MES = MARZO
# FECHA = 2016-01-04 -> MES = ABRIL
# FECHA = 2016-02-04 -> MES = ABRIL
# FECHA = 2016-03-04 -> MES = ABRIL
# FECHA = 2016-04-04 -> MES = ABRIL
# FECHA = 2016-05-04 -> MES = ABRIL
# FECHA = 2016-06-04 -> MES = ABRIL
# FECHA = 2016-07-04 -> MES = ABRIL
# FECHA = 2016-08-04 -> MES = ABRIL
# FECHA = 2016-09-04 -> MES = ABRIL
# FECHA = 2016-10-04 -> MES = ABRIL
# FECHA = 2016-11-04 -> MES = ABRIL
# FECHA = 2016-12-04 -> MES = ABRIL
# FECHA = 2016-04-13 -> MES = ABRIL
# FECHA = 2016-04-14 -> MES = ABRIL
# FECHA = 2016-04-15 -> MES = ABRIL
# FECHA = 2016-04-16 -> MES = ABRIL
# FECHA = 2016-04-17 -> MES = ABRIL
# FECHA = 2016-04-18 -> MES = ABRIL
# FECHA = 2016-04-19 -> MES = ABRIL
# FECHA = 2016-04-20 -> MES = ABRIL
# FECHA = 2016-04-21 -> MES = ABRIL
# FECHA = 2016-04-22 -> MES = ABRIL
# FECHA = 2016-04-23 -> MES = ABRIL
# FECHA = 2016-04-24 -> MES = ABRIL
# FECHA = 2016-04-25 -> MES = ABRIL
# FECHA = 2016-04-26 -> MES = ABRIL
# FECHA = 2016-04-27 -> MES = ABRIL
# FECHA = 2016-04-28 -> MES = ABRIL
# FECHA = 2016-04-29 -> MES = ABRIL
# FECHA = 2016-04-30 -> MES = ABRIL
# FECHA = 2016-01-05 -> MES = MAYO
# FECHA = 2016-02-05 -> MES = MAYO
# FECHA = 2016-03-05 -> MES = MAYO
# FECHA = 2016-04-05 -> MES = MAYO
# FECHA = 2016-05-05 -> MES = MAYO
# FECHA = 2016-06-05 -> MES = MAYO
# FECHA = 2016-07-05 -> MES = MAYO
# FECHA = 2016-08-05 -> MES = MAYO
# FECHA = 2016-09-05 -> MES = MAYO
# FECHA = 2016-10-05 -> MES = MAYO
# FECHA = 2016-11-05 -> MES = MAYO
# FECHA = 2016-12-05 -> MES = MAYO
# FECHA = 2016-05-13 -> MES = MAYO
# FECHA = 2016-05-14 -> MES = MAYO
# FECHA = 2016-05-15 -> MES = MAYO
# FECHA = 2016-05-16 -> MES = MAYO
# FECHA = 2016-05-17 -> MES = MAYO
# FECHA = 2016-05-18 -> MES = MAYO
# FECHA = 2016-05-19 -> MES = MAYO
# FECHA = 2016-05-20 -> MES = MAYO
# FECHA = 2016-05-21 -> MES = MAYO
# FECHA = 2016-05-22 -> MES = MAYO
# FECHA = 2016-05-23 -> MES = MAYO
# FECHA = 2016-05-24 -> MES = MAYO
# FECHA = 2016-05-25 -> MES = MAYO
# FECHA = 2016-05-26 -> MES = MAYO
# FECHA = 2016-05-27 -> MES = MAYO
# FECHA = 2016-05-28 -> MES = MAYO
# FECHA = 2016-05-29 -> MES = MAYO
# FECHA = 2016-05-30 -> MES = MAYO
# FECHA = 2016-05-31 -> MES = MAYO
# FECHA = 2016-01-06 -> MES = JUNIO
# FECHA = 2016-02-06 -> MES = JUNIO
# FECHA = 2016-03-06 -> MES = JUNIO
# FECHA = 2016-04-06 -> MES = JUNIO
# FECHA = 2016-05-06 -> MES = JUNIO
# FECHA = 2016-06-06 -> MES = JUNIO
# FECHA = 2016-07-06 -> MES = JUNIO
# FECHA = 2016-08-06 -> MES = JUNIO
# FECHA = 2016-09-06 -> MES = JUNIO
# FECHA = 2016-10-06 -> MES = JUNIO
# FECHA = 2016-11-06 -> MES = JUNIO
# FECHA = 2016-12-06 -> MES = JUNIO
# FECHA = 2016-06-13 -> MES = JUNIO
# FECHA = 2016-06-14 -> MES = JUNIO
# FECHA = 2016-06-15 -> MES = JUNIO
# FECHA = 2016-06-16 -> MES = JUNIO
# FECHA = 2016-06-17 -> MES = JUNIO
# FECHA = 2016-06-18 -> MES = JUNIO
# FECHA = 2016-06-19 -> MES = JUNIO
# FECHA = 2016-06-20 -> MES = JUNIO
# FECHA = 2016-06-21 -> MES = JUNIO
# FECHA = 2016-06-22 -> MES = JUNIO
# FECHA = 2016-06-23 -> MES = JUNIO
# FECHA = 2016-06-24 -> MES = JUNIO
# FECHA = 2016-06-25 -> MES = JUNIO
# FECHA = 2016-06-26 -> MES = JUNIO
# FECHA = 2016-06-27 -> MES = JUNIO
# FECHA = 2016-06-28 -> MES = JUNIO
# FECHA = 2016-06-29 -> MES = JUNIO
# FECHA = 2016-06-30 -> MES = JUNIO
# FECHA = 2016-01-07 -> MES = JULIO
# FECHA = 2016-02-07 -> MES = JULIO
# FECHA = 2016-03-07 -> MES = JULIO
# FECHA = 2016-04-07 -> MES = JULIO
# FECHA = 2016-05-07 -> MES = JULIO
# FECHA = 2016-06-07 -> MES = JULIO
# FECHA = 2016-07-07 -> MES = JULIO
# FECHA = 2016-08-07 -> MES = JULIO
# FECHA = 2016-09-07 -> MES = JULIO
# FECHA = 2016-10-07 -> MES = JULIO
# FECHA = 2016-11-07 -> MES = JULIO
# FECHA = 2016-12-07 -> MES = JULIO
# FECHA = 2016-07-13 -> MES = JULIO
# FECHA = 2016-07-14 -> MES = JULIO
# FECHA = 2016-07-15 -> MES = JULIO
# FECHA = 2016-07-16 -> MES = JULIO
# FECHA = 2016-07-17 -> MES = JULIO
# FECHA = 2016-07-18 -> MES = JULIO
# FECHA = 2016-07-19 -> MES = JULIO
# FECHA = 2016-07-20 -> MES = JULIO
# FECHA = 2016-07-21 -> MES = JULIO
# FECHA = 2016-07-22 -> MES = JULIO
# FECHA = 2016-07-23 -> MES = JULIO
# FECHA = 2016-07-24 -> MES = JULIO
# FECHA = 2016-07-25 -> MES = JULIO
# FECHA = 2016-07-26 -> MES = JULIO
# FECHA = 2016-07-27 -> MES = JULIO
# FECHA = 2016-07-28 -> MES = JULIO
# FECHA = 2016-07-29 -> MES = JULIO
# FECHA = 2016-07-30 -> MES = JULIO
# FECHA = 2016-07-31 -> MES = JULIO
# FECHA = 2016-01-08 -> MES = AGOSTO
# FECHA = 2016-02-08 -> MES = AGOSTO
# FECHA = 2016-03-08 -> MES = AGOSTO
# FECHA = 2016-04-08 -> MES = AGOSTO
# FECHA = 2016-05-08 -> MES = AGOSTO
# FECHA = 2016-06-08 -> MES = AGOSTO
# FECHA = 2016-07-08 -> MES = AGOSTO
# FECHA = 2016-08-08 -> MES = AGOSTO
# FECHA = 2016-09-08 -> MES = AGOSTO
# FECHA = 2016-10-08 -> MES = AGOSTO
# FECHA = 2016-11-08 -> MES = AGOSTO
# FECHA = 2016-12-08 -> MES = AGOSTO
# FECHA = 2016-08-13 -> MES = AGOSTO
# FECHA = 2016-08-14 -> MES = AGOSTO
# FECHA = 2016-08-15 -> MES = AGOSTO
# FECHA = 2016-08-16 -> MES = AGOSTO
# FECHA = 2016-08-17 -> MES = AGOSTO
# FECHA = 2016-08-18 -> MES = AGOSTO
# FECHA = 2016-08-19 -> MES = AGOSTO
# FECHA = 2016-08-20 -> MES = AGOSTO
# FECHA = 2016-08-21 -> MES = AGOSTO
# FECHA = 2016-08-22 -> MES = AGOSTO
# FECHA = 2016-08-23 -> MES = AGOSTO
# FECHA = 2016-08-24 -> MES = AGOSTO
# FECHA = 2016-08-25 -> MES = AGOSTO
# FECHA = 2016-08-26 -> MES = AGOSTO
# FECHA = 2016-08-27 -> MES = AGOSTO
# FECHA = 2016-08-28 -> MES = AGOSTO
# FECHA = 2016-08-29 -> MES = AGOSTO
# FECHA = 2016-08-30 -> MES = AGOSTO
# FECHA = 2016-08-31 -> MES = AGOSTO
# FECHA = 2016-01-09 -> MES = SEPTIEMBRE
# FECHA = 2016-02-09 -> MES = SEPTIEMBRE
# FECHA = 2016-03-09 -> MES = SEPTIEMBRE
# FECHA = 2016-04-09 -> MES = SEPTIEMBRE
# FECHA = 2016-05-09 -> MES = SEPTIEMBRE
# FECHA = 2016-06-09 -> MES = SEPTIEMBRE
# FECHA = 2016-07-09 -> MES = SEPTIEMBRE
# FECHA = 2016-08-09 -> MES = SEPTIEMBRE
# FECHA = 2016-09-09 -> MES = SEPTIEMBRE
# FECHA = 2016-10-09 -> MES = SEPTIEMBRE
# FECHA = 2016-11-09 -> MES = SEPTIEMBRE
# FECHA = 2016-12-09 -> MES = SEPTIEMBRE
# FECHA = 2016-09-13 -> MES = SEPTIEMBRE
# FECHA = 2016-09-14 -> MES = SEPTIEMBRE
# FECHA = 2016-09-15 -> MES = SEPTIEMBRE
# FECHA = 2016-09-16 -> MES = SEPTIEMBRE
# FECHA = 2016-09-17 -> MES = SEPTIEMBRE
# FECHA = 2016-09-18 -> MES = SEPTIEMBRE
# FECHA = 2016-09-19 -> MES = SEPTIEMBRE
# FECHA = 2016-09-20 -> MES = SEPTIEMBRE
# FECHA = 2016-09-21 -> MES = SEPTIEMBRE
# FECHA = 2016-09-22 -> MES = SEPTIEMBRE
# FECHA = 2016-09-23 -> MES = SEPTIEMBRE
# FECHA = 2016-09-24 -> MES = SEPTIEMBRE
# FECHA = 2016-09-25 -> MES = SEPTIEMBRE
# FECHA = 2016-09-26 -> MES = SEPTIEMBRE
# FECHA = 2016-09-27 -> MES = SEPTIEMBRE
# FECHA = 2016-09-28 -> MES = SEPTIEMBRE
# FECHA = 2016-09-29 -> MES = SEPTIEMBRE
# FECHA = 2016-09-30 -> MES = SEPTIEMBRE
# FECHA = 2016-01-10 -> MES = OCTUBRE
# FECHA = 2016-02-10 -> MES = OCTUBRE
# FECHA = 2016-03-10 -> MES = OCTUBRE
# FECHA = 2016-04-10 -> MES = OCTUBRE
# FECHA = 2016-05-10 -> MES = OCTUBRE
# FECHA = 2016-06-10 -> MES = OCTUBRE
# FECHA = 2016-07-10 -> MES = OCTUBRE
# FECHA = 2016-08-10 -> MES = OCTUBRE
# FECHA = 2016-09-10 -> MES = OCTUBRE
# FECHA = 2016-10-10 -> MES = OCTUBRE
# FECHA = 2016-11-10 -> MES = OCTUBRE
# FECHA = 2016-12-10 -> MES = OCTUBRE
# FECHA = 2016-10-13 -> MES = OCTUBRE
# FECHA = 2016-10-14 -> MES = OCTUBRE
# FECHA = 2016-10-15 -> MES = OCTUBRE
# FECHA = 2016-10-16 -> MES = OCTUBRE
# FECHA = 2016-10-17 -> MES = OCTUBRE
# FECHA = 2016-10-18 -> MES = OCTUBRE
# FECHA = 2016-10-19 -> MES = OCTUBRE
# FECHA = 2016-10-20 -> MES = OCTUBRE
# FECHA = 2016-10-21 -> MES = OCTUBRE
# FECHA = 2016-10-22 -> MES = OCTUBRE
# FECHA = 2016-10-23 -> MES = OCTUBRE
# FECHA = 2016-10-24 -> MES = OCTUBRE
# FECHA = 2016-10-25 -> MES = OCTUBRE
# FECHA = 2016-10-26 -> MES = OCTUBRE
# FECHA = 2016-10-27 -> MES = OCTUBRE
# FECHA = 2016-10-28 -> MES = OCTUBRE
# FECHA = 2016-10-29 -> MES = OCTUBRE
# FECHA = 2016-10-30 -> MES = OCTUBRE
# FECHA = 2016-10-31 -> MES = OCTUBRE
# FECHA = 2016-01-11 -> MES = NOVIEMBRE
# FECHA = 2016-02-11 -> MES = NOVIEMBRE
# FECHA = 2016-03-11 -> MES = NOVIEMBRE
# FECHA = 2016-04-11 -> MES = NOVIEMBRE
# FECHA = 2016-05-11 -> MES = NOVIEMBRE
# FECHA = 2016-06-11 -> MES = NOVIEMBRE
# FECHA = 2016-07-11 -> MES = NOVIEMBRE
# FECHA = 2016-08-11 -> MES = NOVIEMBRE
# FECHA = 2016-09-11 -> MES = NOVIEMBRE
# FECHA = 2016-10-11 -> MES = NOVIEMBRE
# FECHA = 2016-11-11 -> MES = NOVIEMBRE
# FECHA = 2016-12-11 -> MES = NOVIEMBRE
# FECHA = 2016-11-13 -> MES = NOVIEMBRE
# FECHA = 2016-11-14 -> MES = NOVIEMBRE
# FECHA = 2016-11-15 -> MES = NOVIEMBRE
# FECHA = 2016-11-16 -> MES = NOVIEMBRE
# FECHA = 2016-11-17 -> MES = NOVIEMBRE
# FECHA = 2016-11-18 -> MES = NOVIEMBRE
# FECHA = 2016-11-19 -> MES = NOVIEMBRE
# FECHA = 2016-11-20 -> MES = NOVIEMBRE
# FECHA = 2016-11-21 -> MES = NOVIEMBRE
# FECHA = 2016-11-22 -> MES = NOVIEMBRE
# FECHA = 2016-11-23 -> MES = NOVIEMBRE
# FECHA = 2016-11-24 -> MES = NOVIEMBRE
# FECHA = 2016-11-25 -> MES = NOVIEMBRE
# FECHA = 2016-11-26 -> MES = NOVIEMBRE
# FECHA = 2016-11-27 -> MES = NOVIEMBRE
# FECHA = 2016-11-28 -> MES = NOVIEMBRE
# FECHA = 2016-11-29 -> MES = NOVIEMBRE
# FECHA = 2016-11-30 -> MES = NOVIEMBRE
# FECHA = 2016-01-12 -> MES = DICIEMBRE
# FECHA = 2016-02-12 -> MES = DICIEMBRE
# FECHA = 2016-03-12 -> MES = DICIEMBRE
# FECHA = 2016-04-12 -> MES = DICIEMBRE
# FECHA = 2016-05-12 -> MES = DICIEMBRE
# FECHA = 2016-06-12 -> MES = DICIEMBRE
# FECHA = 2016-07-12 -> MES = DICIEMBRE
# FECHA = 2016-08-12 -> MES = DICIEMBRE
# FECHA = 2016-09-12 -> MES = DICIEMBRE
# FECHA = 2016-10-12 -> MES = DICIEMBRE
# FECHA = 2016-11-12 -> MES = DICIEMBRE
# FECHA = 2016-12-12 -> MES = DICIEMBRE
# FECHA = 2016-12-13 -> MES = DICIEMBRE
# FECHA = 2016-12-14 -> MES = DICIEMBRE
# FECHA = 2016-12-15 -> MES = DICIEMBRE
# FECHA = 2016-12-16 -> MES = DICIEMBRE
# FECHA = 2016-12-17 -> MES = DICIEMBRE
# FECHA = 2016-12-18 -> MES = DICIEMBRE
# FECHA = 2016-12-19 -> MES = DICIEMBRE
# FECHA = 2016-12-20 -> MES = DICIEMBRE
# FECHA = 2016-12-21 -> MES = DICIEMBRE
# FECHA = 2016-12-22 -> MES = DICIEMBRE
# FECHA = 2016-12-23 -> MES = DICIEMBRE
# FECHA = 2016-12-24 -> MES = DICIEMBRE
# FECHA = 2016-12-25 -> MES = DICIEMBRE
# FECHA = 2016-12-26 -> MES = DICIEMBRE
# FECHA = 2016-12-27 -> MES = DICIEMBRE
# FECHA = 2016-12-28 -> MES = DICIEMBRE
# FECHA = 2016-12-29 -> MES = DICIEMBRE
# FECHA = 2016-12-30 -> MES = DICIEMBRE
# FECHA = 2016-12-31 -> MES = DICIEMBRE
# FECHA = 2017-01-01 -> MES = ENERO
# FECHA = 2017-02-01 -> MES = ENERO
# FECHA = 2017-03-01 -> MES = ENERO
# FECHA = 2017-04-01 -> MES = ENERO
# FECHA = 2017-05-01 -> MES = ENERO
# FECHA = 2017-06-01 -> MES = ENERO
# FECHA = 2017-07-01 -> MES = ENERO
# FECHA = 2017-08-01 -> MES = ENERO
# FECHA = 2017-09-01 -> MES = ENERO
# FECHA = 2017-10-01 -> MES = ENERO
# FECHA = 2017-11-01 -> MES = ENERO
# FECHA = 2017-12-01 -> MES = ENERO
# FECHA = 2017-01-13 -> MES = ENERO
# FECHA = 2017-01-14 -> MES = ENERO
# FECHA = 2017-01-15 -> MES = ENERO
# FECHA = 2017-01-16 -> MES = ENERO
# FECHA = 2017-01-17 -> MES = ENERO
# FECHA = 2017-01-18 -> MES = ENERO
# FECHA = 2017-01-19 -> MES = ENERO
# FECHA = 2017-01-20 -> MES = ENERO
# FECHA = 2017-01-21 -> MES = ENERO
# FECHA = 2017-01-22 -> MES = ENERO
# FECHA = 2017-01-23 -> MES = ENERO
# FECHA = 2017-01-24 -> MES = ENERO
# FECHA = 2017-01-25 -> MES = ENERO
# FECHA = 2017-01-26 -> MES = ENERO
# FECHA = 2017-01-27 -> MES = ENERO
# FECHA = 2017-01-28 -> MES = ENERO
# FECHA = 2017-01-29 -> MES = ENERO
# FECHA = 2017-01-30 -> MES = ENERO
# FECHA = 2017-01-31 -> MES = ENERO
# FECHA = 2017-02-02 -> MES = FEBRERO
# FECHA = 2017-03-02 -> MES = FEBRERO
# FECHA = 2017-05-02 -> MES = FEBRERO
# FECHA = 2017-04-02 -> MES = FEBRERO
# FECHA = 2017-06-02 -> MES = FEBRERO
# FECHA = 2017-07-02 -> MES = FEBRERO
# FECHA = 2017-08-02 -> MES = FEBRERO
# FECHA = 2017-10-02 -> MES = FEBRERO
# FECHA = 2017-01-02 -> MES = FEBRERO
# FECHA = 2017-09-02 -> MES = FEBRERO
# FECHA = 2017-11-02 -> MES = FEBRERO
# FECHA = 2017-12-02 -> MES = FEBRERO
# FECHA = 2017-02-13 -> MES = FEBRERO
# FECHA = 2017-02-16 -> MES = FEBRERO
# FECHA = 2017-02-17 -> MES = FEBRERO
# FECHA = 2017-02-18 -> MES = FEBRERO
# FECHA = 2017-02-19 -> MES = FEBRERO
# FECHA = 2017-02-20 -> MES = FEBRERO
# FECHA = 2017-02-21 -> MES = FEBRERO
# FECHA = 2017-02-23 -> MES = FEBRERO
# FECHA = 2017-02-24 -> MES = FEBRERO
# FECHA = 2017-02-25 -> MES = FEBRERO
# FECHA = 2017-02-26 -> MES = FEBRERO
# FECHA = 2017-02-15 -> MES = FEBRERO
# FECHA = 2017-02-27 -> MES = FEBRERO
# FECHA = 2017-02-14 -> MES = FEBRERO
# FECHA = 2017-02-22 -> MES = FEBRERO
# FECHA = 2017-01-03 -> MES = MARZO
# FECHA = 2017-02-03 -> MES = MARZO
# FECHA = 2017-05-03 -> MES = MARZO
# FECHA = 2017-07-03 -> MES = MARZO
# FECHA = 2017-08-03 -> MES = MARZO
# FECHA = 2017-09-03 -> MES = MARZO
# FECHA = 2017-10-03 -> MES = MARZO
# FECHA = 2017-11-03 -> MES = MARZO
# FECHA = 2017-12-03 -> MES = MARZO
# FECHA = 2017-03-13 -> MES = MARZO
# FECHA = 2017-03-14 -> MES = MARZO
# FECHA = 2017-03-15 -> MES = MARZO
# FECHA = 2017-03-16 -> MES = MARZO
# FECHA = 2017-03-18 -> MES = MARZO
# FECHA = 2017-03-20 -> MES = MARZO
# FECHA = 2017-03-22 -> MES = MARZO
# FECHA = 2017-03-23 -> MES = MARZO
# FECHA = 2017-04-03 -> MES = MARZO
# FECHA = 2017-03-03 -> MES = MARZO
# FECHA = 2017-03-17 -> MES = MARZO
# FECHA = 2017-03-19 -> MES = MARZO
# FECHA = 2017-03-21 -> MES = MARZO
# FECHA = 2017-06-03 -> MES = MARZO
# FECHA = 2017-03-24 -> MES = MARZO
# FECHA = 2017-03-25 -> MES = MARZO
# FECHA = 2017-03-26 -> MES = MARZO
# FECHA = 2017-03-27 -> MES = MARZO
# FECHA = 2017-02-04 -> MES = ABRIL
# FECHA = 2017-01-04 -> MES = ABRIL
# FECHA = 2017-03-04 -> MES = ABRIL
# FECHA = 2017-04-04 -> MES = ABRIL
# FECHA = 2017-05-04 -> MES = ABRIL
# FECHA = 2017-06-04 -> MES = ABRIL
# FECHA = 2017-07-04 -> MES = ABRIL
# FECHA = 2017-08-04 -> MES = ABRIL
# FECHA = 2017-09-04 -> MES = ABRIL
# FECHA = 2017-10-04 -> MES = ABRIL
# FECHA = 2017-11-04 -> MES = ABRIL
# FECHA = 2017-12-04 -> MES = ABRIL
# FECHA = 2017-04-13 -> MES = ABRIL
# FECHA = 2017-04-14 -> MES = ABRIL
# FECHA = 2017-04-15 -> MES = ABRIL
# FECHA = 2017-04-16 -> MES = ABRIL
# FECHA = 2017-04-17 -> MES = ABRIL
# FECHA = 2017-04-18 -> MES = ABRIL
# FECHA = 2017-04-19 -> MES = ABRIL
# FECHA = 2017-04-20 -> MES = ABRIL
# FECHA = 2017-04-21 -> MES = ABRIL
# FECHA = 2017-04-22 -> MES = ABRIL
# FECHA = 2017-04-23 -> MES = ABRIL
# FECHA = 2017-04-24 -> MES = ABRIL
# FECHA = 2017-04-25 -> MES = ABRIL
# FECHA = 2017-04-26 -> MES = ABRIL
# FECHA = 2017-04-27 -> MES = ABRIL
# FECHA = 2017-04-28 -> MES = ABRIL
# FECHA = 2017-04-29 -> MES = ABRIL
# FECHA = 2017-04-30 -> MES = ABRIL
# FECHA = 2017-03-29 -> MES = MARZO
# FECHA = 2017-03-30 -> MES = MARZO
# FECHA = 2017-03-31 -> MES = MARZO
# FECHA = 2017-03-28 -> MES = MARZO
# FECHA = 2017-01-05 -> MES = MAYO
# FECHA = 2017-02-05 -> MES = MAYO
# FECHA = 2017-03-05 -> MES = MAYO
# FECHA = 2017-04-05 -> MES = MAYO
# FECHA = 2017-07-05 -> MES = MAYO
# FECHA = 2017-08-05 -> MES = MAYO
# FECHA = 2017-10-05 -> MES = MAYO
# FECHA = 2017-11-05 -> MES = MAYO
# FECHA = 2017-12-05 -> MES = MAYO
# FECHA = 2017-05-17 -> MES = MAYO
# FECHA = 2017-05-18 -> MES = MAYO
# FECHA = 2017-05-19 -> MES = MAYO
# FECHA = 2017-05-20 -> MES = MAYO
# FECHA = 2017-05-21 -> MES = MAYO
# FECHA = 2017-05-23 -> MES = MAYO
# FECHA = 2017-05-24 -> MES = MAYO
# FECHA = 2017-05-25 -> MES = MAYO
# FECHA = 2017-05-26 -> MES = MAYO
# FECHA = 2017-05-27 -> MES = MAYO
# FECHA = 2017-05-28 -> MES = MAYO
# FECHA = 2017-05-29 -> MES = MAYO
# FECHA = 2017-05-30 -> MES = MAYO
# FECHA = 2017-05-31 -> MES = MAYO
# FECHA = 2017-05-05 -> MES = MAYO
# FECHA = 2017-05-13 -> MES = MAYO
# FECHA = 2017-05-14 -> MES = MAYO
# FECHA = 2017-05-22 -> MES = MAYO
# FECHA = 2017-06-05 -> MES = MAYO
# FECHA = 2017-09-05 -> MES = MAYO
# FECHA = 2017-05-16 -> MES = MAYO
# FECHA = 2017-05-15 -> MES = MAYO
# FECHA = 2017-02-06 -> MES = JUNIO
# FECHA = 2017-05-06 -> MES = JUNIO
# FECHA = 2017-06-06 -> MES = JUNIO
# FECHA = 2017-08-06 -> MES = JUNIO
# FECHA = 2017-10-06 -> MES = JUNIO
# FECHA = 2017-12-06 -> MES = JUNIO
# FECHA = 2017-06-15 -> MES = JUNIO
# FECHA = 2017-06-20 -> MES = JUNIO
# FECHA = 2017-06-21 -> MES = JUNIO
# FECHA = 2017-06-23 -> MES = JUNIO
# FECHA = 2017-06-28 -> MES = JUNIO
# FECHA = 2017-06-29 -> MES = JUNIO
# FECHA = 2017-01-06 -> MES = JUNIO
# FECHA = 2017-07-06 -> MES = JUNIO
# FECHA = 2017-09-06 -> MES = JUNIO
# FECHA = 2017-06-13 -> MES = JUNIO
# FECHA = 2017-06-14 -> MES = JUNIO
# FECHA = 2017-06-16 -> MES = JUNIO
# FECHA = 2017-06-19 -> MES = JUNIO
# FECHA = 2017-06-22 -> MES = JUNIO
# FECHA = 2017-06-24 -> MES = JUNIO
# FECHA = 2017-06-26 -> MES = JUNIO
# FECHA = 2017-06-27 -> MES = JUNIO
# FECHA = 2017-06-25 -> MES = JUNIO
# FECHA = 2017-04-06 -> MES = JUNIO
# FECHA = 2017-06-17 -> MES = JUNIO
# FECHA = 2017-06-18 -> MES = JUNIO
# FECHA = 2017-06-30 -> MES = JUNIO
# FECHA = 2017-03-06 -> MES = JUNIO
# FECHA = 2017-11-06 -> MES = JUNIO
# FECHA = 2017-01-07 -> MES = JULIO
# FECHA = 2017-02-07 -> MES = JULIO
# FECHA = 2017-03-07 -> MES = JULIO
# FECHA = 2017-04-07 -> MES = JULIO
# FECHA = 2017-05-07 -> MES = JULIO
# FECHA = 2017-06-07 -> MES = JULIO
# FECHA = 2017-08-07 -> MES = JULIO
# FECHA = 2017-07-07 -> MES = JULIO
# FECHA = 2017-09-07 -> MES = JULIO
# FECHA = 2017-10-07 -> MES = JULIO
# FECHA = 2017-11-07 -> MES = JULIO
# FECHA = 2017-12-07 -> MES = JULIO
# FECHA = 2017-07-13 -> MES = JULIO
# FECHA = 2017-07-14 -> MES = JULIO
# FECHA = 2017-07-15 -> MES = JULIO
# FECHA = 2017-07-16 -> MES = JULIO
# FECHA = 2017-07-17 -> MES = JULIO
# FECHA = 2017-07-18 -> MES = JULIO
# FECHA = 2017-07-19 -> MES = JULIO
# FECHA = 2017-07-20 -> MES = JULIO
# FECHA = 2017-07-21 -> MES = JULIO
# FECHA = 2017-07-22 -> MES = JULIO
# FECHA = 2017-07-23 -> MES = JULIO
# FECHA = 2017-07-24 -> MES = JULIO
# FECHA = 2017-07-25 -> MES = JULIO
# FECHA = 2017-07-26 -> MES = JULIO
# FECHA = 2017-07-27 -> MES = JULIO
# FECHA = 2017-07-29 -> MES = JULIO
# FECHA = 2017-07-28 -> MES = JULIO
# FECHA = 2017-07-30 -> MES = JULIO
# FECHA = 2017-07-31 -> MES = JULIO
# FECHA = 2017-01-08 -> MES = AGOSTO
# FECHA = 2017-02-08 -> MES = AGOSTO
# FECHA = 2017-03-08 -> MES = AGOSTO
# FECHA = 2017-04-08 -> MES = AGOSTO
# FECHA = 2017-05-08 -> MES = AGOSTO
# FECHA = 2017-06-08 -> MES = AGOSTO
# FECHA = 2017-07-08 -> MES = AGOSTO
# FECHA = 2017-08-08 -> MES = AGOSTO
# FECHA = 2017-09-08 -> MES = AGOSTO
# FECHA = 2017-10-08 -> MES = AGOSTO
# FECHA = 2017-11-08 -> MES = AGOSTO
# FECHA = 2017-12-08 -> MES = AGOSTO
# FECHA = 2017-08-13 -> MES = AGOSTO
# FECHA = 2017-08-14 -> MES = AGOSTO
# FECHA = 2017-08-15 -> MES = AGOSTO
# FECHA = 2017-08-16 -> MES = AGOSTO
# FECHA = 2017-08-17 -> MES = AGOSTO
# FECHA = 2017-08-18 -> MES = AGOSTO
# FECHA = 2017-08-19 -> MES = AGOSTO
# FECHA = 2017-08-20 -> MES = AGOSTO
# FECHA = 2017-08-21 -> MES = AGOSTO
# FECHA = 2017-08-22 -> MES = AGOSTO
# FECHA = 2017-08-23 -> MES = AGOSTO
# FECHA = 2017-08-25 -> MES = AGOSTO
# FECHA = 2017-08-24 -> MES = AGOSTO
# FECHA = 2017-08-26 -> MES = AGOSTO
# FECHA = 2017-08-27 -> MES = AGOSTO
# FECHA = 2017-08-28 -> MES = AGOSTO
# FECHA = 2017-08-29 -> MES = AGOSTO
# FECHA = 2017-08-30 -> MES = AGOSTO
# FECHA = 2017-08-31 -> MES = AGOSTO
# FECHA = 2017-01-09 -> MES = SEPTIEMBRE
# FECHA = 2017-02-09 -> MES = SEPTIEMBRE
# FECHA = 2017-03-09 -> MES = SEPTIEMBRE
# FECHA = 2017-04-09 -> MES = SEPTIEMBRE
# FECHA = 2017-05-09 -> MES = SEPTIEMBRE
# FECHA = 2017-06-09 -> MES = SEPTIEMBRE
# FECHA = 2017-07-09 -> MES = SEPTIEMBRE
# FECHA = 2017-08-09 -> MES = SEPTIEMBRE
# FECHA = 2017-09-09 -> MES = SEPTIEMBRE
# FECHA = 2017-10-09 -> MES = SEPTIEMBRE
# FECHA = 2017-11-09 -> MES = SEPTIEMBRE
# FECHA = 2017-12-09 -> MES = SEPTIEMBRE
# FECHA = 2017-09-13 -> MES = SEPTIEMBRE
# FECHA = 2017-09-14 -> MES = SEPTIEMBRE
# FECHA = 2017-09-15 -> MES = SEPTIEMBRE
# FECHA = 2017-09-16 -> MES = SEPTIEMBRE
# FECHA = 2017-09-17 -> MES = SEPTIEMBRE
# FECHA = 2017-09-18 -> MES = SEPTIEMBRE
# FECHA = 2017-09-19 -> MES = SEPTIEMBRE
# FECHA = 2017-09-20 -> MES = SEPTIEMBRE
# FECHA = 2017-09-21 -> MES = SEPTIEMBRE
# FECHA = 2017-09-22 -> MES = SEPTIEMBRE
# FECHA = 2017-09-23 -> MES = SEPTIEMBRE
# FECHA = 2017-09-24 -> MES = SEPTIEMBRE
# FECHA = 2017-09-25 -> MES = SEPTIEMBRE
# FECHA = 2017-09-26 -> MES = SEPTIEMBRE
# FECHA = 2017-09-27 -> MES = SEPTIEMBRE
# FECHA = 2017-09-28 -> MES = SEPTIEMBRE
# FECHA = 2017-09-29 -> MES = SEPTIEMBRE
# FECHA = 2017-09-30 -> MES = SEPTIEMBRE
# CALLE = PRADOS DE CIPRES -> MES = ENERO
# CALLE = HACIENDA DE RANCHO -> MES = ENERO
# CALLE = LAGUA DE MAYRAN -> MES = ENERO
# CALLE = AV. NEZAHUALCO -> MES = ENERO
# CALLE = PLAZUELA 13 -> MES = ENERO
# CALLE = LAGO PLAYA -> MES = FEBRERO
# CALLE = AV. LOPEZ MAT -> MES = FEBRERO
# CALLE = AV. SOR JUANA INES DE LA -> MES = FEBRERO
# CALLE = VIRGEN DEL SAGRADO CORAZON DE JE -> MES = MARZO
# CALLE = EX CONVENTO DE CHURUBU -> MES = MARZO
# CALLE = CD. VICTORIA -> MES = MAYO
# CALLE = ENRIQUE GONZALEZ MARTINEZ -> MES = JULIO
# CALLE = BOSQUES DE PANAMA -> MES = AGOSTO
# CALLE = LAGO LADOGA -> MES = AGOSTO
# CALLE = SABIDURIA -> MES = SEPTIEMBRE
# CALLE = AV.10 -> MES = NOVIEMBRE
# CALLE = LAGO ZUG -> MES = NOVIEMBRE
# CALLE = VALLE DEL YANG-TSE -> MES = NOVIEMBRE
# CALLE = 5ta AV -> MES = DICIEMBRE
# CALLE = AV. JONH KENNEDY -> MES = DICIEMBRE
# CALLE = TEOLOYUCAN -> MES = ENERO
# CALLE = AV. CONSTITUCION DE LA REPUBL -> MES = ENERO
# CALLE = VALLE DE FARAONES -> MES = FEBRERO
# CALLE = JORGE LUCKE LOYOLA -> MES = MARZO
# CALLE = CABAYO BALLO -> MES = MARZO
# CALLE = SARA GARCIA -> MES = ABRIL
# CALLE = 2a. AVENIDA -> MES = ABRIL
# CALLE = 6ta AV -> MES = MAYO
# CALLE = ADOLFO LOPEZ MATEOS -> MES = JULIO
# CALLE = FERIA DE L AS FLORES -> MES = JULIO
# CALLE = LA CALANDRIA -> MES = JULIO
# CALLE = 4A AVENIDA -> MES = AGOSTO
# No. = 603 -> MES = ABRIL
# No. = 171 BIS -> MES = JUNIO
# No. = MZ. 53 LT. 10 -> MES = JUNIO
# No. = 596 -> MES = JULIO
# No. = 696 -> MES = SEPTIEMBRE
# No. = MZ-3 -> MES = DICIEMBRE
# No. = 461 -> MES = JULIO
# No. = mar -> MES = SEPTIEMBRE
# No. = mie -> MES = SEPTIEMBRE
# ENTRE_CALLE_1 = SIERRA NEVADA -> MES = ENERO
# ENTRE_CALLE_1 = VALLE DEL VOLGA -> MES = ENERO
# ENTRE_CALLE_1 = BOSQUES DE LOS CONTINEN -> MES = FEBRERO
# ENTRE_CALLE_1 = AV. DR. GUSTAVO B -> MES = FEBRERO
# ENTRE_CALLE_1 = AV. BORDO DE XOCH -> MES = FEBRERO
# ENTRE_CALLE_1 = LAGUNA DE SAN CRI -> MES = FEBRERO
# ENTRE_CALLE_1 = AV. NEZAHUALCOYOT -> MES = FEBRERO
# ENTRE_CALLE_1 = BOSQUES DE ARGELI -> MES = FEBRERO
# ENTRE_CALLE_1 = HACIENDA DE LA NO -> MES = FEBRERO
# ENTRE_CALLE_1 = CTO. REY NEZA -> MES = MARZO
# ENTRE_CALLE_1 = LAGO CHIEM -> MES = MARZO
# ENTRE_CALLE_1 = GLORIETA DE PETROLE -> MES = MARZO
# ENTRE_CALLE_1 = AV. SOR JUANA INES DE -> MES = MARZO
# ENTRE_CALLE_1 = AV. CONTITUCION DE LA -> MES = MARZO
# ENTRE_CALLE_1 = CDA. DE ARDILLA -> MES = MAYO
# ENTRE_CALLE_1 = BOSQUES DE UGANDA -> MES = JULIO
# ENTRE_CALLE_1 = ORIENTE 19 -> MES = JULIO
# ENTRE_CALLE_1 = VALLE GRANDE -> MES = JULIO
# ENTRE_CALLE_1 = COLORINES -> MES = AGOSTO
# ENTRE_CALLE_1 = TENOCHTITLAN -> MES = AGOSTO
# ENTRE_CALLE_1 = AV. 701 -> MES = SEPTIEMBRE
# ENTRE_CALLE_1 = VALLE DEL CEREZO -> MES = NOVIEMBRE
# ENTRE_CALLE_1 = PONIENTE 23 -> MES = DICIEMBRE
# ENTRE_CALLE_1 = VALLE DE CERRATO -> MES = ENERO
# ENTRE_CALLE_1 = PONIENTE 14 -> MES = FEBRERO
# ENTRE_CALLE_1 = HACIENDA DE ATENCO -> MES = ABRIL
# ENTRE_CALLE_1 = AV. COSTITUCION DE LA REPUBLICA -> MES = MARZO
# ENTRE_CALLE_1 = TLANEPANTLA -> MES = JULIO
# ENTRE_CALLE_1 = CERRADA PANTITLAN -> MES = JULIO
# ENTRE_CALLE_1 = AVENIDA 12 -> MES = JULIO
# ENTRE_CALLE_1 = 6a AVENIDA -> MES = JULIO
# ENTRE_CALLE_1 = ZANDUNGA -> MES = AGOSTO
# ENTRE_CALLE_1 = 7A AVENIDA -> MES = AGOSTO
# ENTRE_CALLE_2 = BOSQUES DE UGANDA -> MES = ENERO
# ENTRE_CALLE_2 = AMANECER RANCHE -> MES = FEBRERO
# ENTRE_CALLE_2 = VALLE -> MES = FEBRERO
# ENTRE_CALLE_2 = GUADALUPE VICTORI -> MES = MARZO
# ENTRE_CALLE_2 = GLORIETA DE BUCAR -> MES = MARZO
# ENTRE_CALLE_2 = GLORIETA DE PETRO -> MES = MARZO
# ENTRE_CALLE_2 = CERRADA DE ESCONDI -> MES = MARZO
# ENTRE_CALLE_2 = AV. DR. GUSTAVO B -> MES = MARZO
# ENTRE_CALLE_2 = HACIENDA DE S -> MES = MARZO
# ENTRE_CALLE_2 = GLORIETA DE PETROL -> MES = MARZO
# ENTRE_CALLE_2 = LAGUNA DE TERMINO -> MES = MARZO
# ENTRE_CALLE_2 = GLORIETA DE BUCARE -> MES = MARZO
# ENTRE_CALLE_2 = LAGUNA DE SAN CRISTOB -> MES = MARZO
# ENTRE_CALLE_2 = BOSQUES DE LISBOA -> MES = JUNIO
# ENTRE_CALLE_2 = CDA. ESCONDIDA -> MES = JUNIO
# ENTRE_CALLE_2 = ORIENTE 12 -> MES = JULIO
# ENTRE_CALLE_2 = AV. LOPEZ MATEOS -> MES = JULIO
# ENTRE_CALLE_2 = CUCARACHA -> MES = SEPTIEMBRE
# ENTRE_CALLE_2 = ORIENTE 17 -> MES = DICIEMBRE
# ENTRE_CALLE_2 = IZTLACCIHUATL -> MES = ENERO
# ENTRE_CALLE_2 = AMANECER RANCHER -> MES = ENERO
# ENTRE_CALLE_2 = 4a. AVENIDA -> MES = MARZO
# ENTRE_CALLE_2 = PLAZUELA 19 -> MES = ABRIL
# ENTRE_CALLE_2 = CONSTITUCION DE LA REPUBLICA -> MES = JULIO
# ENTRE_CALLE_2 = BOULEVARD BOSQUES DE AFRICA -> MES = SEPTIEMBRE
# COLONIA = BOSQUES DE ARAGO -> MES = ENERO
# COLONIA = TAMAULIPAS SECCI -> MES = ENERO
# COLONIA = AMPLAICION VICENTE VILLADA -> MES = FEBRERO
# COLONIA = NUEVA SANTA MARTHA -> MES = FEBRERO
# COLONIA = METROPOLITANA 1a. SECCION -> MES = FEBRERO
# COLONIA = EL PALMAR -> MES = MARZO
# COLONIA = BENITO JAUREZ 2a. SECCION -> MES = ABRIL
# COLONIA = BENITO JAUREZ 1a. SECCION -> MES = JUNIO
# COLONIA = BENITO JUAREZ 1ra SECCION -> MES = AGOSTO
# COLONIA = BENITO JUAREZ 2da SECCION -> MES = AGOSTO
# COLONIA = VALLE DE ARAGON I -> MES = AGOSTO
# HORA_INICIO = 03:00 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 15:34 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 01:00 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 01:30 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 8:41 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 08:00 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 00:00 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 00:30 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 9:44 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 09:00 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 01:20 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 07:00 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 08:30 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 13:38 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 06:00 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 02:30 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 14:06 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 09:30 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 1:36 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 8:23 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 05:00 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 1:52 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 14:59 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 0:34 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 15:39 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 23:36 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 1:57 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 02:00 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 1:04 -> DELITO = ROBO A COMERCIO
# HORA_INICIO = 17:59 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 23:31 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 11:23 -> DELITO = EXTORSION
# HORA_INICIO = 09:50 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 10:41 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 09:15 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 21:26 -> DELITO = ROBO A COMERCIO
# HORA_INICIO = 08:15 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 14:28 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 06:10 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 04:00 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 05:30 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 00:10 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 21:16 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 09:40 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 16:42 -> DELITO = ROBO A COMERCIO
# HORA_INICIO = 23:02 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 23:37 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 5:23 -> DELITO = ROBO A CASA HABITACION
# HORA_INICIO = 7:29 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 0:02 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 14:32 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 17:13 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 23:59 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 03:30 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 6:46 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 06:20 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 09:45 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 07:10 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 15:27 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 04:30 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 1:38 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 2:54 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 06:40 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 0:37 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 07:30 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 1:43 -> DELITO = ROBO A COMERCIO
# HORA_INICIO = 23:38 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 23:07 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 14:24 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 06:30 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 3:03 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 10:37 -> DELITO = ROBO A COMERCIO
# HORA_INICIO = 6:29 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 0:51 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 8:47 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 22:53 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 12:06 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 3:56 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 8:48 -> DELITO = ROBO A COMERCIO
# HORA_INICIO = 1:44 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 23:13 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 10:59 -> DELITO = EXTORSION
# HORA_INICIO = 15:18 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 08:45 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 18:52 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 19:44 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 0:09 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 3:26 -> DELITO = ROBO A COMERCIO
# HORA_INICIO = 5:37 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 17:02 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 15:09 -> DELITO = EXTORSION
# HORA_INICIO = 1:14 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 0:24 -> DELITO = HOMICIDIO
# HORA_INICIO = 4:43 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 17:31 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 6:34 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 9:43 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 5:34 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 0:16 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 14:01 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 22:02 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 8:09 -> DELITO = ROBO A CASA HABITACION
# HORA_INICIO = 8:03 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 22:39 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 6:47 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 20:08 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 10:31 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 22:54 -> DELITO = ROBO EN VIA PUBLICA
# HORA_INICIO = 0:43 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 06:50 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 07:40 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 15:07 -> DELITO = ROBO A CASA HABITACION
# HORA_INICIO = 08:40 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 22:48 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 09:10 -> DELITO = ROBO DE VEHICULO
# HORA_INICIO = 00:15 -> DELITO = ROBO DE VEHICULO
# CALLE = LA CHAPARRITA -> DELITO = ROBO DE VEHICULO
# CALLE = PRADOS DE CIPRES -> DELITO = ROBO EN VIA PUBLICA
# CALLE = PLAZUELA 3 -> DELITO = ROBO DE VEHICULO
# CALLE = HACIENDA DE RANCHO -> DELITO = ROBO DE VEHICULO
# CALLE = CTO. REY NEZA -> DELITO = ROBO DE VEHICULO
# CALLE = LAGUA DE MAYRAN -> DELITO = ROBO EN VIA PUBLICA
# CALLE = VALLE DE AMECA -> DELITO = ROBO DE VEHICULO
# CALLE = PRADOS DEL ROBLE -> DELITO = ROBO DE VEHICULO
# CALLE = VIRGINIA -> DELITO = ROBO EN VIA PUBLICA
# CALLE = AV. NEZAHUALCO -> DELITO = ROBO A TRANSPORTE PUBLICO
# CALLE = AV. JOHN KENNEDY -> DELITO = ROBO DE VEHICULO
# CALLE = MERIDA -> DELITO = ROBO DE VEHICULO
# CALLE = TUXTLA GUTIERREZ -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE GUADALUPE -> DELITO = ROBO DE VEHICULO
# CALLE = DIAMANTE -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE SALVIN -> DELITO = ROBO DE VEHICULO
# CALLE = BOSQUES DE THAILANDIA -> DELITO = ROBO A COMERCIO
# CALLE = AV. MARAVILLAS -> DELITO = ROBO DE VEHICULO
# CALLE = AV. LOPEZ MAT -> DELITO = ROBO A CUENTA HABIENTE
# CALLE = COTIJA -> DELITO = ROBO DE VEHICULO
# CALLE = Sin CALLE -> DELITO = ROBO DE VEHICULO
# CALLE = AV. SOR JUANA INES DE LA -> DELITO = ROBO A COMERCIO
# CALLE = 4 MILLONES -> DELITO = ROBO DE VEHICULO
# CALLE = MARAVILLAS -> DELITO = ROBO DE VEHICULO
# CALLE = PLAZAS CENTRAL -> DELITO = ROBO DE VEHICULO
# CALLE = LOPEZ MATEOS -> DELITO = ROBO DE VEHICULO
# CALLE = AV. DE LAS ZAPATAS -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DEL CARMEN -> DELITO = ROBO DE VEHICULO
# CALLE = VIRGEN DEL SAGRADO CORAZON DE JE -> DELITO = ROBO EN VIA PUBLICA
# CALLE = FRANCISCO I MADERO -> DELITO = ROBO DE VEHICULO
# CALLE = EX CONVENTO DE CHURUBU -> DELITO = ROBO DE VEHICULO
# CALLE = 3ra AV -> DELITO = ROBO DE VEHICULO
# CALLE = AV. MORELIA -> DELITO = ROBO DE VEHICULO
# CALLE = LAGO DEL FONDO -> DELITO = ROBO DE VEHICULO
# CALLE = LAGO PEIPUS -> DELITO = ROBO A CASA HABITACION
# CALLE = ORIENTE 26 -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DEL VOLGA -> DELITO = ROBO DE VEHICULO
# CALLE = 5ta AV. -> DELITO = ROBO DE VEHICULO
# CALLE = NEZAHUALCOYOTL -> DELITO = ROBO DE VEHICULO
# CALLE = PLAZA DE SAN PEDRO -> DELITO = ROBO A COMERCIO
# CALLE = SAN JUAN DEL RIO -> DELITO = ROBO DE VEHICULO
# CALLE = XINANTECATL -> DELITO = ROBO DE VEHICULO
# CALLE = BAHIAS DE HUATULCO -> DELITO = ROBO DE VEHICULO
# CALLE = ATZCAPOTZALCO -> DELITO = ROBO DE VEHICULO
# CALLE = AV. 4 -> DELITO = ROBO DE VEHICULO
# CALLE = SILVIA -> DELITO = ROBO DE VEHICULO
# CALLE = AV.  RIVA PALACIO -> DELITO = ROBO DE VEHICULO
# CALLE = CD. VICTORIA -> DELITO = ROBO DE VEHICULO
# CALLE = FLORIPONDIO -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE LUCES -> DELITO = ROBO DE VEHICULO
# CALLE = AV.  CUAUHTEMOC -> DELITO = ROBO DE VEHICULO
# CALLE = TAMOS -> DELITO = ROBO DE VEHICULO
# CALLE = BOSQUES DE CAMERUN -> DELITO = ROBO DE VEHICULO
# CALLE = HACIENDA DE MIMIAHUAPAN -> DELITO = ROBO DE VEHICULO
# CALLE = MALINTZIN -> DELITO = ROBO DE VEHICULO
# CALLE = LATERAL DE AV. BORDO DE XOCHIACA -> DELITO = HOMICIDIO
# CALLE = ZACATECAS -> DELITO = ROBO DE VEHICULO
# CALLE = ANGEL DE LA INDEPENCIA -> DELITO = ROBO DE VEHICULO
# CALLE = CDA. DE INDUSTRIAL -> DELITO = ROBO DE VEHICULO
# CALLE = PRIVADA DE OAXACA -> DELITO = ROBO DE VEHICULO
# CALLE = VIRGEN DE GUADALUPE -> DELITO = ROBO DE VEHICULO
# CALLE = PLAZA DEL CARMEN -> DELITO = ROBO DE VEHICULO
# CALLE = PLAZA DE ARAGON -> DELITO = ROBO DE VEHICULO
# CALLE = AV. VILLA CACAMA -> DELITO = ROBO EN VIA PUBLICA
# CALLE = ALMENDROS -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE AMAZONAS -> DELITO = EXTORSION
# CALLE = HEMICILO A JUAREZ -> DELITO = ROBO DE VEHICULO
# CALLE = EJE 4 -> DELITO = ROBO EN VIA PUBLICA
# CALLE = VALLE  DE SANTIAGO -> DELITO = ROBO DE VEHICULO
# CALLE = LAGO DULCE -> DELITO = ROBO DE VEHICULO
# CALLE = ENRIQUE GONZALEZ MARTINEZ -> DELITO = ROBO DE VEHICULO
# CALLE = BOSQUES DE PANAMA -> DELITO = ROBO A CASA HABITACION
# CALLE = VALLE DE SAN JOSE -> DELITO = ROBO DE VEHICULO
# CALLE = PRADOS DE ACACIA -> DELITO = ROBO EN VIA PUBLICA
# CALLE = XOCHITENCO -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE BALDEBEZANA -> DELITO = ROBO DE VEHICULO
# CALLE = AV. CIRCUITO REY NEZA -> DELITO = ROBO EN VIA PUBLICA
# CALLE = PLAZA DEL ESTUDIANTE -> DELITO = ROBO DE VEHICULO
# CALLE = VIRGEN DE NUESTRA SENORA DE LOURDES -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE COLORADO -> DELITO = ROBO DE VEHICULO
# CALLE = GUILLERMO AGUIRRE FIERRO -> DELITO = ROBO DE VEHICULO
# CALLE = LAS COSTENAS -> DELITO = ROBO DE VEHICULO
# CALLE = CAMPECHE -> DELITO = ROBO DE VEHICULO
# CALLE = VALLEJO -> DELITO = ROBO EN VIA PUBLICA
# CALLE = CDA. DE CAPUCHINAS -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE OAXACA -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE RHIN -> DELITO = EXTORSION
# CALLE = AV.10 -> DELITO = ROBO DE VEHICULO
# CALLE = LA CIGARRA -> DELITO = ROBO DE VEHICULO
# CALLE = LUIS HECHEVERRIA -> DELITO = ROBO DE VEHICULO
# CALLE = BOSQUES DE ROMA -> DELITO = ROBO EN VIA PUBLICA
# CALLE = PLAZA DE ANDALUCIA -> DELITO = ROBO EN VIA PUBLICA
# CALLE = LAGO ZUG -> DELITO = ROBO EN VIA PUBLICA
# CALLE = VALLE DEL YANG-TSE -> DELITO = ROBO EN VIA PUBLICA
# CALLE = VALLE PERDIDO -> DELITO = ROBO DE VEHICULO
# CALLE = BOSQUES DE JAPON -> DELITO = ROBO DE VEHICULO
# CALLE = 5ta AV -> DELITO = ROBO DE VEHICULO
# CALLE = SIMON BOLIVAR -> DELITO = ROBO DE VEHICULO
# CALLE = AV. JONH KENNEDY -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE ANIMAS -> DELITO = ROBO DE VEHICULO
# CALLE = LAGO FRIO -> DELITO = EXTORSION
# CALLE = AV CUAUHTEMOC -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE  DE YUKON -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE MACKENZIE -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE YAQUI -> DELITO = ROBO DE VEHICULO
# CALLE = ROSITA ALVIRES -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DEL MIXTECO -> DELITO = ROBO DE VEHICULO
# CALLE = AV. CONSTITUCION DE LA REPUBL -> DELITO = ROBO A COMERCIO
# CALLE = 6a. AVENIDA -> DELITO = ROBO A CASA HABITACION
# CALLE = PERIFERICO -> DELITO = ROBO EN VIA PUBLICA
# CALLE = LAGUNA DE SAN PEDRO -> DELITO = ROBO EN VIA PUBLICA
# CALLE = AV.  CENTRAL -> DELITO = ROBO DE VEHICULO
# CALLE = SARA GARCIA -> DELITO = ROBO DE VEHICULO
# CALLE = PONIENTE 8 -> DELITO = ROBO DE VEHICULO
# CALLE = MEXICALZINGO -> DELITO = ROBO A CASA HABITACION
# CALLE = 2a. AVENIDA -> DELITO = ROBO A CASA HABITACION
# CALLE = EFREN CARRILLO -> DELITO = ROBO EN VIA PUBLICA
# CALLE = LAS MANANITAS -> DELITO = ROBO EN VIA PUBLICA
# CALLE = 6ta AV -> DELITO = ROBO DE VEHICULO
# CALLE = 4ta AV -> DELITO = ROBO DE VEHICULO
# CALLE = AV. 602 -> DELITO = ROBO DE VEHICULO
# CALLE = PALACION NACIONAL -> DELITO = ROBO EN VIA PUBLICA
# CALLE = VALLE DE ZAMBESI -> DELITO = ROBO DE VEHICULO
# CALLE = SAN CRISTOBAL -> DELITO = ROBO DE VEHICULO
# CALLE = EL CAPIRO -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE RIVAS -> DELITO = ROBO DE VEHICULO
# CALLE = 7 LEGUAS -> DELITO = ROBO DE VEHICULO
# CALLE = AV PANTITLAN -> DELITO = ROBO DE VEHICULO
# CALLE = VALLE DE LIERP -> DELITO = ROBO DE VEHICULO
# CALLE = AV. CUAUTHEMOC -> DELITO = ROBO DE VEHICULO
# CALLE = ADOLFO LOPEZ MATEOS -> DELITO = ROBO DE VEHICULO
# CALLE = LA CALANDRIA -> DELITO = ROBO EN VIA PUBLICA
# CALLE = AV. ANGEL DE LA INDEPENDENCIA -> DELITO = ROBO DE VEHICULO
# CALLE = 4A AVENIDA -> DELITO = ROBO A TRANSPORTE PUBLICO
# No. = 397 -> DELITO = ROBO DE VEHICULO
# No. = 829 -> DELITO = ROBO A COMERCIO
# No. = 326 -> DELITO = ROBO DE VEHICULO
# No. = 1B -> DELITO = ROBO A CASA HABITACION
# No. = 406 -> DELITO = ROBO A CASA HABITACION
# No. = 451 -> DELITO = ROBO A COMERCIO
# No. = 851 -> DELITO = ROBO A COMERCIO
# No. = 546 -> DELITO = ROBO DE VEHICULO
# No. = MZ. 53 LT. 10 -> DELITO = ROBO A CASA HABITACION
# No. = 596 -> DELITO = ROBO A COMERCIO
# No. = 723 -> DELITO = ROBO A COMERCIO
# No. = 424 -> DELITO = ROBO DE VEHICULO
# No. = 344 -> DELITO = ROBO DE VEHICULO
# No. = MZ-3 -> DELITO = ROBO DE VEHICULO
# No. = vie -> DELITO = ROBO A CASA HABITACION
# No. = mar -> DELITO = ROBO A CASA HABITACION
# No. = mie -> DELITO = ROBO A CASA HABITACION
# ENTRE_CALLE_1 = AV. CIRCUITO MEXIQUENSE -> DELITO = ROBO EN VIA PUBLICA
# ENTRE_CALLE_1 = LAGO DE CHAPALA -> DELITO = ROBO EN VIA PUBLICA
# ENTRE_CALLE_1 = SIERRA NEVADA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = VALLE DEL VOLGA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = BOSQUES DE NIGERIA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = LAGO MUSTERS -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = ORIENTE 27 -> DELITO = ROBO A COMERCIO
# ENTRE_CALLE_1 = MICHOACANA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = ANDADOR -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AZUCENA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = GLADIOLA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = ORIENTE 22 -> DELITO = ROBO EN VIA PUBLICA
# ENTRE_CALLE_1 = ALDAMA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = BOSQUES DE LOS CONTINEN -> DELITO = ROBO A CASA HABITACION
# ENTRE_CALLE_1 = AV. DR. GUSTAVO B -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV. BORDO DE XOCH -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV. PENON-TEXCOCO -> DELITO = ROBO EN VIA PUBLICA
# ENTRE_CALLE_1 = PRADOS DE ABEDUL -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV PANTITLAN -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = LAGUNA DE SAN CRI -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV. NEZAHUALCOYOT -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV.PANTITLAN -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = BOSQUES DE ARGELI -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = HACIENDA DE LA NO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV. SOR JUANA INES DE LA -> DELITO = ROBO EN VIA PUBLICA
# ENTRE_CALLE_1 = CTO. REY NEZA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = GLORIETA DE PETROLE -> DELITO = ROBO A CASA HABITACION
# ENTRE_CALLE_1 = HACIENDA LA NORIA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV.  6 -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = MIGUEL NEGRETE -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = JOCOTITLAN -> DELITO = EXTORSION
# ENTRE_CALLE_1 = TEOLOYUCAN -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV. CONTITUCION DE LA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = BIOLOGIA -> DELITO = ROBO A COMERCIO
# ENTRE_CALLE_1 = HACIENDA DE NORIA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = HACIENDA PURISIMA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = CIVISMO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = PLAZAS CENTRAL -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = BOSQUES DE ANGOLA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = VALLE DE CEREZO -> DELITO = ROBO A COMERCIO
# ENTRE_CALLE_1 = AV.CHIMALHUACAN -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = GUILLERMO AGUIRRE FIERRO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = VALLE DE BARDAGI -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = NORTE DEL COLEGIO -> DELITO = HOMICIDIO
# ENTRE_CALLE_1 = AVENIDA 5 -> DELITO = EXTORSION
# ENTRE_CALLE_1 = AV.  PANTITLAN -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = RANCHO SECO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = ALFONSO SIERRA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = CDA. DE ARDILLA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = VALLE  DE YUKON -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = LAGO CUPATITZIO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = VALLEJO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV.3 -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = HACIENDA DE SAN MATEO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = HACIENDA DE ESCONDIDA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = ALELHI -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = TECNICA -> DELITO = ROBO A COMERCIO
# ENTRE_CALLE_1 = IMPLORACION -> DELITO = ROBO EN VIA PUBLICA
# ENTRE_CALLE_1 = VALLE DE DNIEPER -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = PRADOS DE LAUREL -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = NIRES -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = ORIENTE 19 -> DELITO = ROBO A COMERCIO
# ENTRE_CALLE_1 = HACIENDA DE SAN BERNABE -> DELITO = ROBO EN VIA PUBLICA
# ENTRE_CALLE_1 = CABALLITO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = CDA DE ABANDONADO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = HACIENDA DE XAJAY -> DELITO = ROBO A COMERCIO
# ENTRE_CALLE_1 = SAN JERONIMO -> DELITO = ROBO EN VIA PUBLICA
# ENTRE_CALLE_1 = SALTILLO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = PLAZA DE LA REPUBLICA -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = COLORINES -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = ANDADOR 1 -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = TOPACIO -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV.8 -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = PONIENTE 6 -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = VALLE DE ZAMBESI -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV.6 -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV TEPOZANES -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = PONIENTE 21 -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = AV.10 -> DELITO = ROBO DE VEHICULO
# ENTRE_CALLE_1 = BOSQUES DEL CONGO -> DELITO = ROBO EN VIA PUBLICA
# ...
# ENTRE_CALLE_2 = LAGO GINEBRA -> CUADRANTE = C091
# ENTRE_CALLE_2 = HISTORIA -> CUADRANTE = C066
# ENTRE_CALLE_2 = ROMA -> CUADRANTE = C088
# ENTRE_CALLE_2 = LAGO CANEGUN -> CUADRANTE = C034
# ENTRE_CALLE_2 = COYOACAN -> CUADRANTE = C088
# ENTRE_CALLE_2 = CUCARACHA -> CUADRANTE = C102
# ENTRE_CALLE_2 = ORIENTE 25 -> CUADRANTE = C153
# ENTRE_CALLE_2 = MALINCHE -> CUADRANTE = C131
# ENTRE_CALLE_2 = VALLE DE OAXACA -> CUADRANTE = C021
# ENTRE_CALLE_2 = IGNACION LOPEZ RAYON -> CUADRANTE = C151
# ENTRE_CALLE_2 = PRADOS DE PIRULES -> CUADRANTE = C026
# ENTRE_CALLE_2 = ANDADOR S/N -> CUADRANTE = C131
# ENTRE_CALLE_2 = VIRGEN DEL SAGRADO CORAZON -> CUADRANTE = C056
# ENTRE_CALLE_2 = LINDAVISTA -> CUADRANTE = C131
# ENTRE_CALLE_2 = ORIENTE 17 -> CUADRANTE = C153
# ENTRE_CALLE_2 = GUANAJUATO -> CUADRANTE = C143
# ENTRE_CALLE_2 = BOSQUES DE ARABIA -> CUADRANTE = C031
# ENTRE_CALLE_2 = HACIENDA DE PRESILLAS -> CUADRANTE = C024
# ENTRE_CALLE_2 = VALLE  DE YANG-TSE -> CUADRANTE = C013
# ENTRE_CALLE_2 = BOSQUES DE SUECIA -> CUADRANTE = C032
# ENTRE_CALLE_2 = ANGEL DE LA INDEPENDENCIA -> CUADRANTE = C092
# ENTRE_CALLE_2 = TLALPAN -> CUADRANTE = C131
# ENTRE_CALLE_2 = LIRIO -> CUADRANTE = C105
# ENTRE_CALLE_2 = LAGO COLIN -> CUADRANTE = C035
# ENTRE_CALLE_2 = PLAZUELA 19 -> CUADRANTE = C027
# ENTRE_CALLE_2 = HACIENDA DE TOMACOCO -> CUADRANTE = C024
# ENTRE_CALLE_2 = LOPEZ RAYON -> CUADRANTE = C151
# ENTRE_CALLE_2 = ZIHUATANEJO -> CUADRANTE = C143
# ENTRE_CALLE_2 = CIGARRA -> CUADRANTE = C118
# ENTRE_CALLE_2 = MORELOS -> CUADRANTE = C074
# ENTRE_CALLE_2 = JOSE BERNARDO COUTO -> CUADRANTE = C077
# ENTRE_CALLE_2 = 6A AVENIDA -> CUADRANTE = C044
# ENTRE_CALLE_2 = BOULEVARD BOSQUES DE AFRICA -> CUADRANTE = C031
# COLONIA = LAS ARMAS -> CUADRANTE = C026
# COLONIA = LAS ANTENAS -> CUADRANTE = C024
# COLONIA = CIUDAD JARDIN -> CUADRANTE = C046
# COLONIA = JOYAS DE ARAGON -> CUADRANTE = C018
# COLONIA = NUEVA SANTA MARTHA -> CUADRANTE = C136
# COLONIA = METROPOLITANA 1a. SECCION -> CUADRANTE = C081
# COLONIA = EL PALMAR -> CUADRANTE = C105
# COLONIA = NP -> CUADRANTE = Sin CUADRANTE
# COLONIA = LA PALMAS -> CUADRANTE = C066
# COLONIA = EJIDOS DE SAN AGUSTIN -> CUADRANTE = C144
# COLONIA = EL PORVENIR -> CUADRANTE = C071
# COLONIA = BENITO JAUREZ 1a. SECCION -> CUADRANTE = C093
# COLONIA = BENITO JUAREZ 1ra SECCION -> CUADRANTE = C107
# SECTOR = Sin SECTOR -> CUADRANTE = Sin CUADRANTE
# HORA_INICIO = 18:17 -> TURNO = 2
# HORA_INICIO = 6:06 -> TURNO = 2
# HORA_INICIO = 9:59 -> TURNO = 1
# HORA_INICIO = 2:48 -> TURNO = 2
# HORA_INICIO = 15:42 -> TURNO = 1
# HORA_INICIO = 01:20 -> TURNO = 1
# HORA_INICIO = 4:34 -> TURNO = 1
# HORA_INICIO = 10:18 -> TURNO = 1
# HORA_INICIO = 12:21 -> TURNO = 3
# HORA_INICIO = 9:27 -> TURNO = 3
# HORA_INICIO = 11:47 -> TURNO = 3
# HORA_INICIO = 8:04 -> TURNO = 3
# HORA_INICIO = 20:53 -> TURNO = 3
# HORA_INICIO = 14:06 -> TURNO = 2
# HORA_INICIO = 1:36 -> TURNO = 2
# HORA_INICIO = 20:59 -> TURNO = 3
# HORA_INICIO = 23:57 -> TURNO = 3
# HORA_INICIO = 18:46 -> TURNO = 2
# HORA_INICIO = 8:52 -> TURNO = 1
# HORA_INICIO = 14:59 -> TURNO = 3
# HORA_INICIO = 14:19 -> TURNO = 3
# HORA_INICIO = 23:24 -> TURNO = 1
# HORA_INICIO = 16:41 -> TURNO = 3
# HORA_INICIO = 19:56 -> TURNO = 3
# HORA_INICIO = 20:27 -> TURNO = 2
# HORA_INICIO = 6:41 -> TURNO = 2
# HORA_INICIO = 5:04 -> TURNO = 2
# HORA_INICIO = 18:03 -> TURNO = 3
# HORA_INICIO = 2:09 -> TURNO = 2
# HORA_INICIO = 16:42 -> TURNO = 1
# HORA_INICIO = 9:42 -> TURNO = 3
# HORA_INICIO = 23:37 -> TURNO = 1
# HORA_INICIO = 8:31 -> TURNO = 1
# HORA_INICIO = 5:23 -> TURNO = 3
# HORA_INICIO = 7:44 -> TURNO = 3
# HORA_INICIO = 18:23 -> TURNO = 3
# HORA_INICIO = 17:12 -> TURNO = 3
# HORA_INICIO = 19:24 -> TURNO = 3
# HORA_INICIO = 23:59 -> TURNO = 3
# HORA_INICIO = 06:20 -> TURNO = 1
# HORA_INICIO = 3:58 -> TURNO = 1
# HORA_INICIO = 14:44 -> TURNO = 2
# HORA_INICIO = 8:58 -> TURNO = 1
# HORA_INICIO = 18:02 -> TURNO = 3
# HORA_INICIO = 2:54 -> TURNO = 3
# HORA_INICIO = 21:17 -> TURNO = 1
# HORA_INICIO = 23:58 -> TURNO = 1
# HORA_INICIO = 23:38 -> TURNO = 3
# HORA_INICIO = 10:01 -> TURNO = 3
# HORA_INICIO = 9:39 -> TURNO = 3
# HORA_INICIO = 5:09 -> TURNO = 1
# HORA_INICIO = 8:26 -> TURNO = 3
# HORA_INICIO = 12:46 -> TURNO = 3
# HORA_INICIO = 3:03 -> TURNO = 3
# HORA_INICIO = 9:41 -> TURNO = 3
# HORA_INICIO = 13:48 -> TURNO = 1
# HORA_INICIO = 8:47 -> TURNO = 3
# HORA_INICIO = 6:21 -> TURNO = 3
# HORA_INICIO = 9:53 -> TURNO = 1
# HORA_INICIO = 22:53 -> TURNO = 3
# HORA_INICIO = 8:33 -> TURNO = 2
# HORA_INICIO = 12:06 -> TURNO = 1
# HORA_INICIO = 22:28 -> TURNO = 3
# HORA_INICIO = 6:18 -> TURNO = 2
# HORA_INICIO = 15:22 -> TURNO = 1
# HORA_INICIO = 17:54 -> TURNO = 1
# HORA_INICIO = 0:09 -> TURNO = 3
# HORA_INICIO = 4:47 -> TURNO = 2
# HORA_INICIO = 4:06 -> TURNO = 3
# HORA_INICIO = 3:26 -> TURNO = 2
# HORA_INICIO = 5:37 -> TURNO = 2
# HORA_INICIO = 14:21 -> TURNO = 2
# HORA_INICIO = 15:09 -> TURNO = 3
# HORA_INICIO = 3:28 -> TURNO = 3
# HORA_INICIO = 12:54 -> TURNO = 3
# HORA_INICIO = 19:04 -> TURNO = 3
# HORA_INICIO = 3:23 -> TURNO = 3
# HORA_INICIO = 9:38 -> TURNO = 2
# HORA_INICIO = 5:34 -> TURNO = 3
# HORA_INICIO = 18:47 -> TURNO = 2
# HORA_INICIO = 0:16 -> TURNO = 3
# HORA_INICIO = 16:49 -> TURNO = 3
# HORA_INICIO = 22:02 -> TURNO = 3
# HORA_INICIO = 8:09 -> TURNO = 3
# HORA_INICIO = 6:59 -> TURNO = 2
# HORA_INICIO = 1:26 -> TURNO = 1
# HORA_INICIO = 8:42 -> TURNO = 2
# HORA_INICIO = 9:22 -> TURNO = 3
# HORA_INICIO = 9:26 -> TURNO = 3
# HORA_INICIO = 6:47 -> TURNO = 2
# HORA_INICIO = 0:56 -> TURNO = 2
# HORA_INICIO = 21:47 -> TURNO = 3
# HORA_INICIO = 14:38 -> TURNO = 3
# HORA_INICIO = 16:39 -> TURNO = 3
# HORA_INICIO = 21:24 -> TURNO = 3
# HORA_INICIO = 2:39 -> TURNO = 3
# HORA_INICIO = 9:49 -> TURNO = 3
# HORA_INICIO = 9:47 -> TURNO = 2
# HORA_INICIO = 23:53 -> TURNO = 3
# HORA_INICIO = 9:24 -> TURNO = 1
# HORA_INICIO = 0:43 -> TURNO = 2
# HORA_INICIO = 16:28 -> TURNO = 3
# HORA_INICIO = 2:33 -> TURNO = 2
# HORA_INICIO = 21:34 -> TURNO = 3
# HORA_INICIO = 11:07 -> TURNO = 3
# HORA_INICIO = 2:24 -> TURNO = 3
# HORA_INICIO = 0:48 -> TURNO = 1
# HORA_INICIO = 22:48 -> TURNO = 3
# HORA_INICIO = 7:14 -> TURNO = 3
# HORA_INICIO = 00:15 -> TURNO = 3
# HORA_INICIO = 12:47 -> TURNO = 2
# CALLE = PLAZUELA 3 -> TURNO = 3
# CALLE = CALLE 40 -> TURNO = 2
# CALLE = LAGUA DE MAYRAN -> TURNO = 1
# CALLE = VALLE DE AMECA -> TURNO = 2
# CALLE = AV. JORGE LUQUE LOYOLA -> TURNO = 3
# CALLE = DIAMANTE -> TURNO = 3
# CALLE = EMILIANO ZAPATA -> TURNO = 3
# CALLE = AV. CIRCUITO MEXIQUENSE -> TURNO = 2
# CALLE = PLAZUELA 13 -> TURNO = 3
# CALLE = CIVISMO -> TURNO = 2
# CALLE = LAGO PLAYA -> TURNO = 3
# CALLE = Sin CALLE -> TURNO = 1
# CALLE = LAGO MUSTERS -> TURNO = 3
# CALLE = 4 MILLONES -> TURNO = 1
# CALLE = CALLE 36 -> TURNO = 2
# CALLE = SALTILLO -> TURNO = 2
# CALLE = PORTAL DE MERCADERES -> TURNO = 1
# CALLE = EX CONVENTO DE CHURUBU -> TURNO = 1
# CALLE = CARLOS HANK GONZALEZ -> TURNO = 2
# CALLE = LAGO DEL FONDO -> TURNO = 1
# CALLE = AV. MORELOS -> TURNO = 2
# CALLE = TACOPAINTZIN -> TURNO = 1
# CALLE = PLAZAS DE SAN PEDRO -> TURNO = 3
# CALLE = AV.  RIVA PALACIO -> TURNO = 3
# CALLE = CD. VICTORIA -> TURNO = 3
# CALLE = SANTA MARIA -> TURNO = 2
# CALLE = RIO DE LOS REMEDIOS -> TURNO = 3
# CALLE = TAMOS -> TURNO = 2
# CALLE = HACIENDA DE MIMIAHUAPAN -> TURNO = 2
# CALLE = MALINTZIN -> TURNO = 2
# CALLE = BOSQUES DE TANGER -> TURNO = 3
# CALLE = SEIS MILLONES -> TURNO = 3
# CALLE = VALLE DE MATAMOROS -> TURNO = 3
# CALLE = BOSQUES DE SUIZA -> TURNO = 2
# CALLE = LAGO LA DOGA -> TURNO = 3
# CALLE = ENRIQUE GONZALEZ -> TURNO = 3
# CALLE = BOSQUES DE ETIOPIA -> TURNO = 2
# CALLE = CUAUTLA -> TURNO = 2
# CALLE = HEMICILO A JUAREZ -> TURNO = 2
# CALLE = CALLE 38 -> TURNO = 3
# CALLE = VALLE CARRIZAL DE LOS ALGUALES -> TURNO = 1
# CALLE = ENRIQUE GONZALEZ MARTINEZ -> TURNO = 2
# CALLE = BOSQUES DE PANAMA -> TURNO = 3
# CALLE = SABIDURIA -> TURNO = 2
# CALLE = PLAZA DEL ESTUDIANTE -> TURNO = 1
# CALLE = VIRGEN DE NUESTRA SENORA DE LOURDES -> TURNO = 3
# CALLE = GUILLERMO AGUIRRE FIERRO -> TURNO = 1
# CALLE = LAS COSTENAS -> TURNO = 2
# CALLE = HACIENDA DE ZOTOLUCA -> TURNO = 1
# CALLE = VALLEJO -> TURNO = 1
# CALLE = MAGDALENA -> TURNO = 2
# CALLE = VALLE DE RHIN -> TURNO = 1
# CALLE = LA CIGARRA -> TURNO = 1
# CALLE = LUIS HECHEVERRIA -> TURNO = 2
# CALLE = LAGO ZUG -> TURNO = 2
# CALLE = VIRGEN DE LA DOLOROSA -> TURNO = 2
# CALLE = VALLE DE RODANO -> TURNO = 3
# CALLE = AV. RANCHO GRANDE -> TURNO = 2
# CALLE = SIMON BOLIVAR -> TURNO = 1
# CALLE = VALLE DE ANIMAS -> TURNO = 3
# CALLE = VALLE DE SAN FRANCISCO -> TURNO = 1
# CALLE = TEOLOYUCAN -> TURNO = 3
# CALLE = ROSITA ALVIRES -> TURNO = 1
# CALLE = VALLE DEL MIXTECO -> TURNO = 3
# CALLE = VALLE DE FARAONES -> TURNO = 1
# CALLE = VALLE DE RIERO -> TURNO = 3
# CALLE = AVENIDA 4 -> TURNO = 1
# CALLE = LAGUNA DE SAN PEDRO -> TURNO = 1
# CALLE = PONIENTE 8 -> TURNO = 3
# CALLE = MEXICALZINGO -> TURNO = 2
# CALLE = AV. JHON F. KENNEDY -> TURNO = 3
# CALLE = 6ta AV -> TURNO = 2
# CALLE = 4ta AV -> TURNO = 2
# CALLE = AV. 602 -> TURNO = 1
# CALLE = VALLE DE ZAMBESI -> TURNO = 3
# CALLE = AV PANTITLAN -> TURNO = 1
# CALLE = AV. CUAUTHEMOC -> TURNO = 1
# CALLE = CUAHUTEMOC -> TURNO = 2
# CALLE = ADOLFO LOPEZ MATEOS -> TURNO = 2
# CALLE = SAN MATEO -> TURNO = 2
# CALLE = FERIA DE L AS FLORES -> TURNO = 1
# CALLE = AV. ANGEL DE LA INDEPENDENCIA -> TURNO = 3
# No. = 417 -> TURNO = 2
# No. = 460 -> TURNO = 3
# No. = 363 -> TURNO = 1
# No. = 397 -> TURNO = 3
# No. = 470 -> TURNO = 2
# No. = 436 -> TURNO = 2
# No. = 221 -> TURNO = 3
# No. = 326 -> TURNO = 2
# No. = 1B -> TURNO = 1
# No. = 448 -> TURNO = 2
# No. = 400 -> TURNO = 1
# No. = 851 -> TURNO = 3
# No. = 423 -> TURNO = 1
# No. = 413 -> TURNO = 2
# No. = 361 -> TURNO = 3
# No. = MZ-3 -> TURNO = 2
# No. = 449 -> TURNO = 3
# ENTRE_CALLE_1 = CRISANTEMO -> TURNO = 3
# ENTRE_CALLE_1 = NEZAHUALCOYOTL -> TURNO = 3
# ENTRE_CALLE_1 = LAGO PATZCUARO -> TURNO = 1
# ENTRE_CALLE_1 = PLAZA DE SAN PEDRO -> TURNO = 1
# ENTRE_CALLE_1 = BOSQUES DE NIGERIA -> TURNO = 1
# ENTRE_CALLE_1 = 6 MILLONES -> TURNO = 1
# ENTRE_CALLE_1 = BOSQUES DE GUINEA -> TURNO = 1
# ENTRE_CALLE_1 = EX CONVENTO DE CHURUBUSCO -> TURNO = 2
# ENTRE_CALLE_1 = HACIENDA DE TORRECILLAS -> TURNO = 2
# ENTRE_CALLE_1 = AZUCENA -> TURNO = 2
# ENTRE_CALLE_1 = LIRIO -> TURNO = 1
# ENTRE_CALLE_1 = BOSQUES DE LOS CONTINEN -> TURNO = 2
# ENTRE_CALLE_1 = LAS ISABELES -> TURNO = 1
# ENTRE_CALLE_1 = LAGUNA DE SAN CRI -> TURNO = 3
# ENTRE_CALLE_1 = GLORIETA DE PETRO -> TURNO = 2
# ENTRE_CALLE_1 = GUSTAVO BAZ PRADA -> TURNO = 3
# ENTRE_CALLE_1 = CTO. REY NEZA -> TURNO = 3
# ENTRE_CALLE_1 = VALLE DE GUERRA -> TURNO = 1
# ENTRE_CALLE_1 = HACIENDA LA NORIA -> TURNO = 1
# ENTRE_CALLE_1 = AV.  6 -> TURNO = 3
# ENTRE_CALLE_1 = AV. VILLA CACAMA -> TURNO = 1
# ENTRE_CALLE_1 = GUILLERMO AGUIRRE -> TURNO = 1
# ENTRE_CALLE_1 = TEOLOYUCAN -> TURNO = 2
# ENTRE_CALLE_1 = MANZANILLO -> TURNO = 3
# ENTRE_CALLE_1 = COATLINCHAN -> TURNO = 1
# ENTRE_CALLE_1 = CEREZOS -> TURNO = 1
# ENTRE_CALLE_1 = BOSQUES DE INGLATERRA -> TURNO = 1
# ENTRE_CALLE_1 = PRADOS DE ACACIA -> TURNO = 3
# ENTRE_CALLE_1 = CIVISMO -> TURNO = 2
# ENTRE_CALLE_1 = BOSQUES DE ANGOLA -> TURNO = 2
# ENTRE_CALLE_1 = MERCADERES -> TURNO = 2
# ENTRE_CALLE_1 = AV.  PANTITLAN -> TURNO = 3
# ENTRE_CALLE_1 = AV.  CHIMALHUACAN -> TURNO = 2
# ENTRE_CALLE_1 = BELISARIO DOMINGUEZ -> TURNO = 3
# ENTRE_CALLE_1 = TEPEYAC -> TURNO = 3
# ENTRE_CALLE_1 = TURMALINA -> TURNO = 2
# ENTRE_CALLE_1 = OMBULES -> TURNO = 2
# ENTRE_CALLE_1 = AV.3 -> TURNO = 2
# ENTRE_CALLE_1 = HACIENDA DE SAN MATEO -> TURNO = 2
# ENTRE_CALLE_1 = GUILLERMO AGUIRRE Y FIERRO -> TURNO = 1
# ENTRE_CALLE_1 = ALELHI -> TURNO = 1
# ENTRE_CALLE_1 = BOSQUES DE HOLANDA -> TURNO = 2
# ENTRE_CALLE_1 = EUCALIPTOS -> TURNO = 1
# ENTRE_CALLE_1 = PONIENTE 10 -> TURNO = 2
# ENTRE_CALLE_1 = PRADOS DE LAUREL -> TURNO = 2
# ENTRE_CALLE_1 = NIRES -> TURNO = 2
# ENTRE_CALLE_1 = ORIENTE 19 -> TURNO = 1
# ENTRE_CALLE_1 = HACIENDA DE CORRALEJO -> TURNO = 2
# ENTRE_CALLE_1 = VALLE GRANDE -> TURNO = 3
# ENTRE_CALLE_1 = CABALLITO -> TURNO = 1
# ENTRE_CALLE_1 = HEMICICLO A JUAREZ -> TURNO = 3
# ENTRE_CALLE_1 = ORIENTE 29 -> TURNO = 1
# ENTRE_CALLE_1 = SANTA MARTHA -> TURNO = 3
# ENTRE_CALLE_1 = SALTILLO -> TURNO = 2
# ENTRE_CALLE_1 = ME VOY -> TURNO = 1
# ENTRE_CALLE_1 = BOSQUES DE POLONIA -> TURNO = 3
# ENTRE_CALLE_1 = PLAZA DE LA REPUBLICA -> TURNO = 1
# ENTRE_CALLE_1 = COLORINES -> TURNO = 2
# ENTRE_CALLE_1 = PLAZUELA 3 -> TURNO = 1
# ENTRE_CALLE_1 = AV.8 -> TURNO = 3
# ENTRE_CALLE_1 = VALLE DE ZAMBESI -> TURNO = 2
# ENTRE_CALLE_1 = PLAZAS DE SAN PEDRO -> TURNO = 2
# ENTRE_CALLE_1 = 4 MILLONES -> TURNO = 2
# ENTRE_CALLE_1 = PONIENTE 1 -> TURNO = 2
# ENTRE_CALLE_1 = GRACIANO SANCHEZ -> TURNO = 3
# ENTRE_CALLE_1 = MARIA BUSTILLOS -> TURNO = 1
# ENTRE_CALLE_1 = MIGUEL HIDALGO Y COSTILLA -> TURNO = 3
# ENTRE_CALLE_1 = PIPILA -> TURNO = 2
# ENTRE_CALLE_1 = HACIENDA DE MAYORAZGO -> TURNO = 3
# ENTRE_CALLE_1 = AV VICENTE VILLADA -> TURNO = 1
# ENTRE_CALLE_1 = NUESTRA SENORA DE LOURDES -> TURNO = 2
# ENTRE_CALLE_1 = PORTAL DE MERCADERES -> TURNO = 1
# ENTRE_CALLE_1 = OTUMBA -> TURNO = 2
# ENTRE_CALLE_1 = PONIENTE 14 -> TURNO = 3
# ENTRE_CALLE_1 = FISICA -> TURNO = 2
# ENTRE_CALLE_1 = PROFESA -> TURNO = 3
# ENTRE_CALLE_1 = BOSQUES DE VENEZUELA -> TURNO = 2
# ENTRE_CALLE_1 = FRANCISCO ZARCO -> TURNO = 2
# ENTRE_CALLE_1 = BORDO DE XOCHIACA -> TURNO = 1
# ENTRE_CALLE_1 = 7ma AV -> TURNO = 1
# ENTRE_CALLE_1 = PERIFERICO -> TURNO = 3
# ENTRE_CALLE_1 = LAGO HIELMAR -> TURNO = 3
# ENTRE_CALLE_1 = EXCONVENTO DE CHURUBUSCO -> TURNO = 3
# ENTRE_CALLE_1 = VALLE  DE LAS ZAPATAS -> TURNO = 2
# ENTRE_CALLE_1 = AV MEXICO -> TURNO = 1
# ENTRE_CALLE_1 = TLANEPANTLA -> TURNO = 2
# ENTRE_CALLE_1 = 6a AVENIDA -> TURNO = 2
# ENTRE_CALLE_1 = 7A AVENIDA -> TURNO = 3
# ENTRE_CALLE_2 = AV PANTITLAN -> TURNO = 1
# ENTRE_CALLE_2 = BOSQUES DE UGANDA -> TURNO = 1
# ENTRE_CALLE_2 = TEOLOYUCAN -> TURNO = 1
# ENTRE_CALLE_2 = BOSQUES DE ESPANA -> TURNO = 2
# ENTRE_CALLE_2 = IGNACIO ALLENDE -> TURNO = 3
# ENTRE_CALLE_2 = 6ta AV -> TURNO = 3
# ENTRE_CALLE_2 = GLORIETA DE PET -> TURNO = 1
# ENTRE_CALLE_2 = AV. JUAREZ -> TURNO = 1
# ENTRE_CALLE_2 = VALLE -> TURNO = 3
# ENTRE_CALLE_2 = CALLE 4 -> TURNO = 2
# ENTRE_CALLE_2 = ACAPULCO -> TURNO = 3
# ENTRE_CALLE_2 = PRADOS DE CAOBA -> TURNO = 3
# ENTRE_CALLE_2 = ABANDONADO -> TURNO = 3
# ENTRE_CALLE_2 = GLORIETA DE PETRO -> TURNO = 3
# ENTRE_CALLE_2 = IZTACIHUATL -> TURNO = 3
# ENTRE_CALLE_2 = CERRADA DE ESCONDI -> TURNO = 2
# ENTRE_CALLE_2 = ARDILLA -> TURNO = 3
# ENTRE_CALLE_2 = GLORIETA DE BUCARE -> TURNO = 2
# ENTRE_CALLE_2 = LAGUNA DE SAN CRISTOB -> TURNO = 1
# ENTRE_CALLE_2 = COMILLAS -> TURNO = 3
# ENTRE_CALLE_2 = CALLE 38 -> TURNO = 3
# ENTRE_CALLE_2 = ORIENTE 24 -> TURNO = 3
# ENTRE_CALLE_2 = PROFESA -> TURNO = 2
# ENTRE_CALLE_2 = AV. FLORESTA -> TURNO = 3
# ENTRE_CALLE_2 = BOSQUES DE COREA -> TURNO = 2
# ENTRE_CALLE_2 = BOSQUES DE BIRMANIA -> TURNO = 3
# ENTRE_CALLE_2 = MARIQUITA -> TURNO = 3
# ENTRE_CALLE_2 = SIERRA NEVADA -> TURNO = 2
# ENTRE_CALLE_2 = PLAZA DE LAS TRES CULTURAS -> TURNO = 1
# ENTRE_CALLE_2 = LAGO MICHIGAN -> TURNO = 2
# ENTRE_CALLE_2 = BALBINO DAVALOS -> TURNO = 3
# ENTRE_CALLE_2 = BOSQUES DE LAS NACIONES -> TURNO = 1
# ENTRE_CALLE_2 = ROSAS DE MAYO -> TURNO = 3
# ENTRE_CALLE_2 = PONIENTE 25 -> TURNO = 2
# ENTRE_CALLE_2 = BOSQUES DE DINAMARCA -> TURNO = 2
# ENTRE_CALLE_2 = MANUEL MARIA CONTRERAS -> TURNO = 1
# ENTRE_CALLE_2 = ORIENTE 12 -> TURNO = 2
# ENTRE_CALLE_2 = PAJARO AZUL -> TURNO = 1
# ENTRE_CALLE_2 = LAGO ATHER -> TURNO = 3
# ENTRE_CALLE_2 = PLAZA DE MIRAVALLE -> TURNO = 1
# ENTRE_CALLE_2 = HISTORIA -> TURNO = 1
# ENTRE_CALLE_2 = ROMA -> TURNO = 3
# ENTRE_CALLE_2 = GUERRILLERA -> TURNO = 1
# ENTRE_CALLE_2 = VALLE DE OAXACA -> TURNO = 2
# ENTRE_CALLE_2 = BUCARELI -> TURNO = 1
# ENTRE_CALLE_2 = PRADOS DE PIRULES -> TURNO = 3
# ENTRE_CALLE_2 = SULTEPEC -> TURNO = 3
# ENTRE_CALLE_2 = CALANDRIA -> TURNO = 2
# ENTRE_CALLE_2 = ORIENTE 17 -> TURNO = 2
# ENTRE_CALLE_2 = BOSQUES DE SUECIA -> TURNO = 3
# ENTRE_CALLE_2 = ANGEL DE LA INDEPENDENCIA -> TURNO = 3
# ENTRE_CALLE_2 = VICENTE VILLADA -> TURNO = 2
# ENTRE_CALLE_2 = TLALPAN -> TURNO = 1
# ENTRE_CALLE_2 = LIRIO -> TURNO = 3
# ENTRE_CALLE_2 = PLAZUELA 19 -> TURNO = 1
# ENTRE_CALLE_2 = COCHERAS -> TURNO = 2
# ENTRE_CALLE_2 = PERIFERICO -> TURNO = 1
# ENTRE_CALLE_2 = ZIHUATANEJO -> TURNO = 2
# ENTRE_CALLE_2 = 6A AVENIDA -> TURNO = 3
# ENTRE_CALLE_2 = BOULEVARD BOSQUES DE AFRICA -> TURNO = 1
# COLONIA = BENITO JUAREZ 3a SECCION -> TURNO = 2
# COLONIA = AMPLAICION VICENTE VILLADA -> TURNO = 2
# COLONIA = EJIDOS DE SAN AGUSTIN -> TURNO = 3
# COLONIA = EL PORVENIR -> TURNO = 3
# COLONIA = BENITO JUAREZ 2da SECCION -> TURNO = 1
# COLONIA = VALLE DE ARAGON I -> TURNO = 3

# %% [markdown]
# ## Quitar dependencias funcionales triviales
# Quitamos todas aquellas dependencias funcionales que se dan por estar contenidas dentro de otro conjunto.
